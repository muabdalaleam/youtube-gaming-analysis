# %% [markdown]
# ## <center> **<span style="color: red">EDA</span> and <span style="color: red">Feature engineering</span> steps**

# %% [markdown]
# In this section we will do two things not one as before first thing we will do first thing will be<br>
# the feature engineering so we can draw more conclusions in the EDA.<br><br>
# We will save the interactive plots here to make an interactive dashboard application but we will do<br>
# this in other file.
#
# **Important note**: we will not create new data frames variations in this code but we will create<br>
# code that will generate new useful features or drop useless feature this code will be save to use<br>
# later in the ML phase.

# %% [markdown]
# ##### **Questions we will ask with <span style = "color: red">SMART</span> method**:
# 1. What's the correlation type between likes, views, comments & duration in minutes
# 2. Whats' the highest game gaining views, likes, comments
# 3. How can channels's total videos count affect it's subscribers count and where's the minimum <br>
# sweet spot for videos count
# 4. What's the highest videos quality geographic places in terms of likes via time.
# 5.

# %% [markdown]
# ##### **Anaysis we will make based on the question**:
# 1. Correlation analysis for the features.
# 2. Bar charts and analysis for the categorical variabels.
# 3. Analysis for the **tags** column and all things about it.
# 4. Time series analysis for the features change in time.
# 5. Anomaly analysis and see the top youtubers and thier videos.
# 6. Analysis for each game growth and views.
# 7. Geographic analysis for the statistics of the data.<br>
#
# "And many others after we extract more features."

# %% [markdown]
# ##### **Features we will extract**:
# 1. How many videos uploads for each channels per month.
# 3. How long is the video's title and describtion
# 4. Does the youtuber has twitter, facebook, instgram etc.. account
# 5. The average video stats per channel
# 6. Some extra boolean features

# %% [markdown]
# ## <center> **Importing the <span style="color: red">Packeges</span>**

# %%
import ast
import json
from dash import html
import pandas as pd
import numpy as np
import plotly
import matplotlib
# import pycountry
import plotly.io as pio
import plotly.subplots as sp
import seaborn as sns
from datetime import datetime
import plotly.offline as pyo
from collections import Counter

import plotly.graph_objects as go 
import plotly.express as px
from scipy import stats
import sqlite3
import pickle

from plotly.offline import iplot, download_plotlyjs
from plotly.utils import PlotlyJSONEncoder
from IPython.display import set_matplotlib_formats
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
THEME_COLORS = ["#2e2e2e", "#fc0303"]
NUMERICS = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64',
            'uint16', 'uint32', 'uint64']


pio.templates.default = "ggplot2"
pyo.init_notebook_mode(connected= True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.20.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## <center> **Loading the <span style="color: red">data frames</span>**

# %%
con = sqlite3.connect('../database.db')

base_channels = pd.read_pickle("../Cleaned files/base_channels.pickle")
base_videos = pd.read_pickle("../Cleaned files/base_videos.pickle")
base_games = pd.read_pickle("../Cleaned files/base_games.pickle")

stacked_channels = pd.read_pickle("../Cleaned files/stacked_channels.pickle")
stacked_videos = pd.read_pickle("../Cleaned files/stacked_videos.pickle")
stacked_games = pd.read_pickle("../Cleaned files/stacked_games_df.pickle")


base_channels_videos = pd.read_sql_query("""      

                       SELECT *
                       FROM base_videos
                       
                       INNER JOIN base_channels ON
                           channelTitle = channel_name""", con)

stacked_base_videos = pd.read_sql_query("""   

                        SELECT * 
                        FROM base_videos AS bv

                        INNER JOIN stacked_videos  AS sv ON
                            sv.video_id = bv.video_id""", con)

stacked_base_videos = stacked_base_videos.head(50_000)

stacked_base_channels = pd.read_sql_query("""   

                        SELECT * 
                        FROM base_channels AS bc

                        INNER JOIN stacked_channels  AS sc ON
                            sc.channel_name = bc.channel_name""", con)

con.close()

base_channels_videos.drop(["channel_name"], axis= 1,
                           inplace= True)

stacked_base_videos = stacked_base_videos.loc[:,~stacked_base_videos.columns.duplicated()].copy()
stacked_base_channels = stacked_base_channels.loc[:,~stacked_base_channels.columns.duplicated()].copy()

base_channels_videos["date"] = pd.to_datetime(base_channels_videos["date"])


for stacked_base in [stacked_base_videos, stacked_base_channels]:
    stacked_base["Collecting date"] = pd.to_datetime(stacked_base["Collecting date"], format="%Y_%m_%d")


cm = sns.light_palette(THEME_COLORS[1], as_cmap=True)
stacked_base_channels.sample(5).style.background_gradient(cmap=cm)
# Out:
# <style type="text/css">
# #T_938c9_row0_col1, #T_938c9_row0_col2, #T_938c9_row1_col4 {
#   background-color: #fc0303;
#   color: #f1f1f1;
# }
# #T_938c9_row0_col4 {
#   background-color: #f4dcdc;
#   color: #000000;
# }
# #T_938c9_row1_col1 {
#   background-color: #f4dbdb;
#   color: #000000;
# }
# #T_938c9_row1_col2 {
#   background-color: #f77a7a;
#   color: #f1f1f1;
# }
# #T_938c9_row2_col1, #T_938c9_row2_col2, #T_938c9_row2_col4 {
#   background-color: #f3f0f0;
#   color: #000000;
# }
# #T_938c9_row3_col1 {
#   background-color: #f3efef;
#   color: #000000;
# }
# #T_938c9_row3_col2 {
#   background-color: #f3ecec;
#   color: #000000;
# }
# #T_938c9_row3_col4 {
#   background-color: #f3e0e0;
#   color: #000000;
# }
# #T_938c9_row4_col1 {
#   background-color: #f3ebeb;
#   color: #000000;
# }
# #T_938c9_row4_col2 {
#   background-color: #f5c0c0;
#   color: #000000;
# }
# #T_938c9_row4_col4 {
#   background-color: #f87070;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_938c9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_938c9_level0_col0" class="col_heading level0 col0" >channel_name</th>
#       <th id="T_938c9_level0_col1" class="col_heading level0 col1" >subscribers</th>
#       <th id="T_938c9_level0_col2" class="col_heading level0 col2" >total_views</th>
#       <th id="T_938c9_level0_col3" class="col_heading level0 col3" >date</th>
#       <th id="T_938c9_level0_col4" class="col_heading level0 col4" >video_count</th>
#       <th id="T_938c9_level0_col5" class="col_heading level0 col5" >about</th>
#       <th id="T_938c9_level0_col6" class="col_heading level0 col6" >country</th>
#       <th id="T_938c9_level0_col7" class="col_heading level0 col7" >Collecting date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_938c9_level0_row0" class="row_heading level0 row0" >7969</th>
#       <td id="T_938c9_row0_col0" class="data row0 col0" >BUDI01 GAMING</td>
#       <td id="T_938c9_row0_col1" class="data row0 col1" >13200000</td>
#       <td id="T_938c9_row0_col2" class="data row0 col2" >1125193739</td>
#       <td id="T_938c9_row0_col3" class="data row0 col3" >2019-07-19 00:00:00</td>
#       <td id="T_938c9_row0_col4" class="data row0 col4" >297</td>
#       <td id="T_938c9_row0_col5" class="data row0 col5" >Contact us :
#
# Instagram : budisembrenget
# https://www.instagram.com/budisembrenget
# Facebook : https://www.facebook.com/BUDI01GAMINGOfficial
# Discord : https://discord.gg/akCT7BeuUd
#
# Email : budigamingofficial9@gmail.com
#
# Est : 2018
# </td>
#       <td id="T_938c9_row0_col6" class="data row0 col6" >ID</td>
#       <td id="T_938c9_row0_col7" class="data row0 col7" >2023-04-27 00:00:00</td>
#     </tr>
#     <tr>
#       <th id="T_938c9_level0_row1" class="row_heading level0 row1" >19721</th>
#       <td id="T_938c9_row1_col0" class="data row1 col0" >Fius Gamer</td>
#       <td id="T_938c9_row1_col1" class="data row1 col1" >1230000</td>
#       <td id="T_938c9_row1_col2" class="data row1 col2" >560096662</td>
#       <td id="T_938c9_row1_col3" class="data row1 col3" >2015-01-17 00:00:00</td>
#       <td id="T_938c9_row1_col4" class="data row1 col4" >1784</td>
#       <td id="T_938c9_row1_col5" class="data row1 col5" >Il progetto Fius Gamer nasce il 17 gennaio 2015. A muoverlo è la passione per il Gaming, Fifa ed il calcio in generale. L’azzurro Napoli è il colore della nostra vita e le reactions alle gare dei partenopei sono diventate un marchio di fabbrica. Prank, riflessioni sul mondo pallonaro, Challenges e tanto altro. Siamo in evoluzione così come lo è il mondo, ma il motto è e resterà….CARICHI COME NON MAI!</td>
#       <td id="T_938c9_row1_col6" class="data row1 col6" >IT</td>
#       <td id="T_938c9_row1_col7" class="data row1 col7" >2023-06-04 00:00:00</td>
#     </tr>
#     <tr>
#       <th id="T_938c9_level0_row2" class="row_heading level0 row2" >16109</th>
#       <td id="T_938c9_row2_col0" class="data row2 col0" >Neonity Gaming</td>
#       <td id="T_938c9_row2_col1" class="data row2 col1" >15300</td>
#       <td id="T_938c9_row2_col2" class="data row2 col2" >2400094</td>
#       <td id="T_938c9_row2_col3" class="data row2 col3" >2021-09-10 00:00:00</td>
#       <td id="T_938c9_row2_col4" class="data row2 col4" >155</td>
#       <td id="T_938c9_row2_col5" class="data row2 col5" >Fortnite videók és streamek minden nap!
# </td>
#       <td id="T_938c9_row2_col6" class="data row2 col6" >HU</td>
#       <td id="T_938c9_row2_col7" class="data row2 col7" >2023-05-01 00:00:00</td>
#     </tr>
#     <tr>
#       <th id="T_938c9_level0_row3" class="row_heading level0 row3" >23368</th>
#       <td id="T_938c9_row3_col0" class="data row3 col0" >Gaming While Black</td>
#       <td id="T_938c9_row3_col1" class="data row3 col1" >74700</td>
#       <td id="T_938c9_row3_col2" class="data row3 col2" >23567197</td>
#       <td id="T_938c9_row3_col3" class="data row3 col3" >2021-05-03 00:00:00</td>
#       <td id="T_938c9_row3_col4" class="data row3 col4" >268</td>
#       <td id="T_938c9_row3_col5" class="data row3 col5" >Games and culture from our perspective. This is Gaming While Black. Subscribe for more videos and join our community on https://gamingwhileblack.show!
#
# </td>
#       <td id="T_938c9_row3_col6" class="data row3 col6" >US</td>
#       <td id="T_938c9_row3_col7" class="data row3 col7" >2023-04-15 00:00:00</td>
#     </tr>
#     <tr>
#       <th id="T_938c9_level0_row4" class="row_heading level0 row4" >11422</th>
#       <td id="T_938c9_row4_col0" class="data row4 col0" >MSI Gaming</td>
#       <td id="T_938c9_row4_col1" class="data row4 col1" >320000</td>
#       <td id="T_938c9_row4_col2" class="data row4 col2" >233816898</td>
#       <td id="T_938c9_row4_col3" class="data row4 col3" >2013-01-14 00:00:00</td>
#       <td id="T_938c9_row4_col4" class="data row4 col4" >1039</td>
#       <td id="T_938c9_row4_col5" class="data row4 col5" >As a world leading gaming brand, MSI is the most trusted name in gaming and eSports. We stand by our principles of breakthroughs in design, the pursuit of excellence, and technological innovation. Integrating gamers' most coveted extreme performance, realistic visuals, authentic sound, precise control and smooth streaming functions into its gaming rigs, MSI frees gamers from tedious trial and error and pushes gaming performance beyond limits. The determination to surpass past achievements has made MSI a ‘True Gaming’ brand with gaming spirit throughout the industry!</td>
#       <td id="T_938c9_row4_col6" class="data row4 col6" >TW</td>
#       <td id="T_938c9_row4_col7" class="data row4 col7" >2023-04-15 00:00:00</td>
#     </tr>
#   </tbody>
# </table>

# %%
base_channels_videos.describe().style.background_gradient(cmap=cm)
# Out:
# <style type="text/css">
# #T_28f5c_row0_col0, #T_28f5c_row0_col4, #T_28f5c_row0_col5, #T_28f5c_row1_col0, #T_28f5c_row1_col3, #T_28f5c_row1_col8, #T_28f5c_row2_col0, #T_28f5c_row2_col1, #T_28f5c_row2_col2, #T_28f5c_row2_col3, #T_28f5c_row2_col4, #T_28f5c_row2_col5, #T_28f5c_row2_col7, #T_28f5c_row2_col8, #T_28f5c_row3_col0, #T_28f5c_row3_col1, #T_28f5c_row3_col2, #T_28f5c_row3_col3, #T_28f5c_row3_col4, #T_28f5c_row3_col5, #T_28f5c_row3_col8, #T_28f5c_row4_col0, #T_28f5c_row4_col1, #T_28f5c_row4_col2, #T_28f5c_row4_col3, #T_28f5c_row4_col8, #T_28f5c_row5_col0, #T_28f5c_row5_col1, #T_28f5c_row5_col3, #T_28f5c_row5_col8, #T_28f5c_row6_col8, #T_28f5c_row7_col8 {
#   background-color: #f3f0f0;
#   color: #000000;
# }
# #T_28f5c_row0_col1, #T_28f5c_row4_col5 {
#   background-color: #f3eeee;
#   color: #000000;
# }
# #T_28f5c_row0_col2 {
#   background-color: #f6a0a0;
#   color: #000000;
# }
# #T_28f5c_row0_col3, #T_28f5c_row0_col7, #T_28f5c_row0_col8, #T_28f5c_row6_col0, #T_28f5c_row6_col1, #T_28f5c_row6_col2, #T_28f5c_row6_col4, #T_28f5c_row6_col5 {
#   background-color: #fc0303;
#   color: #f1f1f1;
# }
# #T_28f5c_row1_col1, #T_28f5c_row1_col2, #T_28f5c_row4_col4, #T_28f5c_row5_col2, #T_28f5c_row7_col3 {
#   background-color: #f3efef;
#   color: #000000;
# }
# #T_28f5c_row1_col4, #T_28f5c_row4_col7, #T_28f5c_row5_col5, #T_28f5c_row7_col2 {
#   background-color: #f3e9e9;
#   color: #000000;
# }
# #T_28f5c_row1_col5 {
#   background-color: #f3e6e6;
#   color: #000000;
# }
# #T_28f5c_row1_col7 {
#   background-color: #f3e4e4;
#   color: #000000;
# }
# #T_28f5c_row3_col7 {
#   background-color: #f3eded;
#   color: #000000;
# }
# #T_28f5c_row5_col4 {
#   background-color: #f3eaea;
#   color: #000000;
# }
# #T_28f5c_row5_col7 {
#   background-color: #f3e1e1;
#   color: #000000;
# }
# #T_28f5c_row6_col3 {
#   background-color: #f4d9d9;
#   color: #000000;
# }
# #T_28f5c_row6_col7 {
#   background-color: #f69999;
#   color: #000000;
# }
# #T_28f5c_row7_col0 {
#   background-color: #f3ebeb;
#   color: #000000;
# }
# #T_28f5c_row7_col1 {
#   background-color: #f3e8e8;
#   color: #000000;
# }
# #T_28f5c_row7_col4 {
#   background-color: #f4dbdb;
#   color: #000000;
# }
# #T_28f5c_row7_col5 {
#   background-color: #f4d5d5;
#   color: #000000;
# }
# #T_28f5c_row7_col7 {
#   background-color: #f3e2e2;
#   color: #000000;
# }
# </style>
# <table id="T_28f5c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_28f5c_level0_col0" class="col_heading level0 col0" >viewCount</th>
#       <th id="T_28f5c_level0_col1" class="col_heading level0 col1" >likeCount</th>
#       <th id="T_28f5c_level0_col2" class="col_heading level0 col2" >commentCount</th>
#       <th id="T_28f5c_level0_col3" class="col_heading level0 col3" >duration_in_minutes</th>
#       <th id="T_28f5c_level0_col4" class="col_heading level0 col4" >subscribers</th>
#       <th id="T_28f5c_level0_col5" class="col_heading level0 col5" >total_views</th>
#       <th id="T_28f5c_level0_col6" class="col_heading level0 col6" >date</th>
#       <th id="T_28f5c_level0_col7" class="col_heading level0 col7" >video_count</th>
#       <th id="T_28f5c_level0_col8" class="col_heading level0 col8" >avg_uploads_per_month</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_28f5c_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_28f5c_row0_col0" class="data row0 col0" >19343.000000</td>
#       <td id="T_28f5c_row0_col1" class="data row0 col1" >19343.000000</td>
#       <td id="T_28f5c_row0_col2" class="data row0 col2" >19343.000000</td>
#       <td id="T_28f5c_row0_col3" class="data row0 col3" >19343.000000</td>
#       <td id="T_28f5c_row0_col4" class="data row0 col4" >19343.000000</td>
#       <td id="T_28f5c_row0_col5" class="data row0 col5" >19343.000000</td>
#       <td id="T_28f5c_row0_col6" class="data row0 col6" >19343</td>
#       <td id="T_28f5c_row0_col7" class="data row0 col7" >19343.000000</td>
#       <td id="T_28f5c_row0_col8" class="data row0 col8" >19343.000000</td>
#     </tr>
#     <tr>
#       <th id="T_28f5c_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_28f5c_row1_col0" class="data row1 col0" >360349.763170</td>
#       <td id="T_28f5c_row1_col1" class="data row1 col1" >11811.349997</td>
#       <td id="T_28f5c_row1_col2" class="data row1 col2" >407.953316</td>
#       <td id="T_28f5c_row1_col3" class="data row1 col3" >46.647296</td>
#       <td id="T_28f5c_row1_col4" class="data row1 col4" >1135767.049113</td>
#       <td id="T_28f5c_row1_col5" class="data row1 col5" >262671207.996329</td>
#       <td id="T_28f5c_row1_col6" class="data row1 col6" >2017-11-21 01:04:05.856381952</td>
#       <td id="T_28f5c_row1_col7" class="data row1 col7" >988.942822</td>
#       <td id="T_28f5c_row1_col8" class="data row1 col8" >5.348232</td>
#     </tr>
#     <tr>
#       <th id="T_28f5c_level0_row2" class="row_heading level0 row2" >min</th>
#       <td id="T_28f5c_row2_col0" class="data row2 col0" >1.000000</td>
#       <td id="T_28f5c_row2_col1" class="data row2 col1" >1.000000</td>
#       <td id="T_28f5c_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_28f5c_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_28f5c_row2_col4" class="data row2 col4" >61.000000</td>
#       <td id="T_28f5c_row2_col5" class="data row2 col5" >1.000000</td>
#       <td id="T_28f5c_row2_col6" class="data row2 col6" >2006-06-30 00:00:00</td>
#       <td id="T_28f5c_row2_col7" class="data row2 col7" >1.000000</td>
#       <td id="T_28f5c_row2_col8" class="data row2 col8" >0.005263</td>
#     </tr>
#     <tr>
#       <th id="T_28f5c_level0_row3" class="row_heading level0 row3" >25%</th>
#       <td id="T_28f5c_row3_col0" class="data row3 col0" >3372.000000</td>
#       <td id="T_28f5c_row3_col1" class="data row3 col1" >140.000000</td>
#       <td id="T_28f5c_row3_col2" class="data row3 col2" >9.000000</td>
#       <td id="T_28f5c_row3_col3" class="data row3 col3" >7.000000</td>
#       <td id="T_28f5c_row3_col4" class="data row3 col4" >49400.000000</td>
#       <td id="T_28f5c_row3_col5" class="data row3 col5" >7848593.000000</td>
#       <td id="T_28f5c_row3_col6" class="data row3 col6" >2015-12-19 00:00:00</td>
#       <td id="T_28f5c_row3_col7" class="data row3 col7" >260.000000</td>
#       <td id="T_28f5c_row3_col8" class="data row3 col8" >1.661972</td>
#     </tr>
#     <tr>
#       <th id="T_28f5c_level0_row4" class="row_heading level0 row4" >50%</th>
#       <td id="T_28f5c_row4_col0" class="data row4 col0" >24777.000000</td>
#       <td id="T_28f5c_row4_col1" class="data row4 col1" >1206.000000</td>
#       <td id="T_28f5c_row4_col2" class="data row4 col2" >63.000000</td>
#       <td id="T_28f5c_row4_col3" class="data row4 col3" >13.570312</td>
#       <td id="T_28f5c_row4_col4" class="data row4 col4" >236000.000000</td>
#       <td id="T_28f5c_row4_col5" class="data row4 col5" >45433503.000000</td>
#       <td id="T_28f5c_row4_col6" class="data row4 col6" >2018-09-20 00:00:00</td>
#       <td id="T_28f5c_row4_col7" class="data row4 col7" >559.000000</td>
#       <td id="T_28f5c_row4_col8" class="data row4 col8" >3.570312</td>
#     </tr>
#     <tr>
#       <th id="T_28f5c_level0_row5" class="row_heading level0 row5" >75%</th>
#       <td id="T_28f5c_row5_col0" class="data row5 col0" >136209.000000</td>
#       <td id="T_28f5c_row5_col1" class="data row5 col1" >5815.500000</td>
#       <td id="T_28f5c_row5_col2" class="data row5 col2" >260.000000</td>
#       <td id="T_28f5c_row5_col3" class="data row5 col3" >31.640625</td>
#       <td id="T_28f5c_row5_col4" class="data row5 col4" >863000.000000</td>
#       <td id="T_28f5c_row5_col5" class="data row5 col5" >189310658.000000</td>
#       <td id="T_28f5c_row5_col6" class="data row5 col6" >2020-06-13 00:00:00</td>
#       <td id="T_28f5c_row5_col7" class="data row5 col7" >1263.000000</td>
#       <td id="T_28f5c_row5_col8" class="data row5 col8" >7.246667</td>
#     </tr>
#     <tr>
#       <th id="T_28f5c_level0_row6" class="row_heading level0 row6" >max</th>
#       <td id="T_28f5c_row6_col0" class="data row6 col0" >119872567.000000</td>
#       <td id="T_28f5c_row6_col1" class="data row6 col1" >1787829.000000</td>
#       <td id="T_28f5c_row6_col2" class="data row6 col2

# %%
stacked_games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1494 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   video_id         1494 non-null   object
#  1   viewCount        1494 non-null   object
#  2   likeCount        1494 non-null   object
#  3   commentCount     1494 non-null   object
#  4   game             1494 non-null   object
#  5   Collecting date  1494 non-null   object
# dtypes: object(6)
# memory usage: 81.7+ KB

# %% [markdown]
# ## <center> **Feature <span style="color: red">Engineering</span>**

# %% [markdown]
# #### *Avg uploads per month*

# %%
# We will take the diffrence between channel' s starting date and the data base creaton date.
base_channels["avg_uploads_per_month"] = base_channels["video_count"] / (
    
    (pd.Series(np.full(len(base_channels),
                      datetime.strptime("2032-4-16", '%Y-%m-%d'))).dt.to_period('M') -
    base_channels["date"].dt.to_period('M')).apply(lambda x: x.n)
).astype(np.float16)


base_channels_videos["avg_uploads_per_month"] = base_channels_videos["video_count"] / (
    
    (pd.Series(np.full(len(base_channels_videos),
                      datetime.strptime("2032-4-16", '%Y-%m-%d'))).dt.to_period('M') -
    base_channels_videos["date"].dt.to_period('M')).apply(lambda x: x.n)
).astype(np.float16)

# %%
base_channels.head()
# Out:
#                    channel_name  subscribers  total_views       date  \
# 0                  ERWIN GAMING       134000     28551971 2021-10-17
# 1             Sport Gaming Live        36400       246665 2021-05-11
# 2  الجندي جيمنج _ELGENDY GAMING        47800      5936930 2021-06-23
# 3                 Yousef Gaming      1790000     95599249 2016-11-05
# 4               Gaming Gangs HD       346000    103937897 2018-11-27
#
#    video_count                                              about country  \
# 0          382                I like playing games with mods. 😁☺️      SG
# 1           48  Welcome to my channel.\nThank you for supporti...      ID
# 2          773  عمر الجندي👑 فيفا موبايل - تقريبا يومى كله فيفا...      EG
# 3          270  سلام عليكم حبايبي في قناة الألعاب\nهنا في Yous...      SA
# 4           84  We are focusing on Quality not Quantity 🥰🥰 \nW...      US
#
#    avg_uploads_per_month
# 0               3.031746
# 1               0.366412
# 2               5.946154
# 3               1.459459
# 4               0.521739

# %% [markdown]
# #### *Video title & describtion length*

# %%
base_channels_videos["description_length"] = base_channels_videos["description"].str.len()
base_videos["description_length"] = base_videos["description"].str.len()

# %%
base_channels_videos["title_length"] = base_channels_videos["title"].str.len()
base_videos["title_length"] = base_videos["title"].str.len()

# %%
base_channels_videos["channel_name_length"] = base_channels_videos["channelTitle"].str.len()
base_channels["channel_name_length"] = base_channels["channel_name"].str.len()

# %%
print("Here's the first 5 rows for describtion length col:\n", 
      base_videos["description_length"][:5])
# Out:
# Here's the first 5 rows for describtion length col:
#  0    1218
# 1    1249
# 2    2671
# 3     742
# 4    1011
# Name: description_length, dtype: int64

# %% [markdown]
# #### *Social media accounts*

# %%
for df in [base_games, base_videos, base_channels_videos, base_channels]:
    
    if df is base_channels:
        col = "about"
    else:    
        col = "description"
        
    df["have_twitter_account"] = df[col].str.contains("twitter")
    df["have_instgram_account"] = df[col].str.contains("instagram")
    df["have_facebook_account"] = df[col].str.contains("facebook")
    df["have_twitch_account"] = df[col].str.contains("twitch")

# %%
base_channels_videos.sample(5)
# Out:
#           video_id                             channelTitle  \
# 2469   7W_OhOQTPfw                            Teches Gaming
# 12985  OaLedGcg-h4                              Swan Gaming
# 15002  g7Gu_eNTq9g                            Senpai Gaming
# 10994  q88XYB1e-Fk                             PAYAL GAMING
# 7168   NMmRc6hTtKY  European Gaming and Betting Association
#
#                                                    title  \
# 2469                    De la 0 la CHALLANGER pe LOL | 1
# 12985  CE KIRBY EST TROP FORT !!! (Kirby and the Forg...
# 15002  Elgato's Facecam Pro is the HIGHEST quality we...
# 10994               ROAD TO 29 LAKH  💞 || PAYAL IS LIVE😘
# 7168   [Presentation] Consumer protection & online ga...
#
#                                              description  \
# 2469   No, de acum în fiecare zi de miercuri, de la o...
# 12985  Salut à tous !\nCE KIRBY EST TROP FORT !!! (Ki...
# 15002  YOUTUBE ►► https://youtube.com/harrisheller\nD...
# 10994  https://linktr.ee/AMDgaminguniverse\n\n➤ Becom...
# 7168   Dr Margaret Carran of City, University of Lond...
#
#                                                     tags  \
# 2469   ['teches', 'bogdan', 'teches gaming', 'league ...
# 12985  ['swan', 'swan gaming', 'swan the voice', 'Kir...
# 15002  ['Alpha Gaming', 'Stream Doctor', 'OBS', 'Tips...
# 10994  ['PAYAL', 'PAYAL GAMING', 'Payal gaming LIVE',...
# 7168   ['Online', 'Gambling', 'Betting', 'iGaming', '...
#
#                      publishedAt  viewCount  likeCount  commentCount  \
# 2469   2022-09-14 14:56:15+00:00      11727       1371           117
# 12985  2022-04-20 08:00:08+00:00     268779       2434             1
# 15002  2023-03-15 14:32:45+00:00      16403        813            35
# 10994  2023-02-26 21:03:44+00:00     128310      14365           133
# 7168   2021-11-03 15:23:43+00:00        111          1             1
#
#       definition  ...                                              about  \
# 2469          hd  ...
# 12985         hd  ...  Salut les gars c'est Swan ! 😄\nIci on délire 🤪...
# 15002         hd  ...  Live Streaming in a nutshell | Camera/Mic Revi...
# 10994         hd  ...  Hey there! Welcome to my channel! My name is P...
# 7168          hd  ...  The European Gaming and Betting Association (E...
#
#        country  avg_uploads_per_month description_length  title_length  \
# 2469        RO               0.425806                413            32
# 12985       FR               3.157143                112            83
# 15002       US               2.205405               1229            69
# 10994       IN               3.878981               1010            36
# 7168        BE               0.176768                439           100
#
#       channel_name_length have_twitter_account  have_instgram_account  \
# 2469                   13                False                  False
# 12985                  11                False                  False
# 15002                  13                 True                  False
# 10994                  12                 True                   True
# 7168                   39                False                  False
#
#        have_facebook_account  have_twitch_account
# 2469                   False                False
# 12985                  False                False
# 15002                  False                False
# 10994                  False                False
# 7168                   False                False
#
# [5 rows x 25 columns]

# %% [markdown]
# #### *Average video stats per channel*

# %%
base_channels_videos["video_count"][
    base_channels_videos["video_count"] == 0] += 1
# We will add one to avoid zero division error

base_channels_videos["avg_views_count"] = (
    base_channels_videos["total_views"] / base_channels_videos["video_count"]).astype(
        np.uint32)

base_channels_videos["avg_like_count"] = (
    base_channels_videos.groupby(
        "channelTitle")["likeCount"].transform("mean")).astype(np.uint32)
# Out:
# C:\Users\FreeComp\AppData\Local\Temp\ipykernel_26064\2117194662.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
unique_views = base_channels_videos.groupby(
    'channelTitle')['avg_views_count'].mean(
     ).reset_index(name='avg_views_count').rename(
     columns= {"channelTitle": "channel_name"})

unique_likes = base_channels_videos.groupby(
    'channelTitle')['avg_like_count'].mean(
     ).reset_index(name='avg_like_count').rename(
     columns= {"channelTitle": "channel_name"})

base_channels = pd.merge(base_channels, unique_likes, on='channel_name', how='left')
base_channels = pd.merge(base_channels, unique_views, on='channel_name', how='left')

# %% [markdown]
# ## <center> **<span style="color: red">Exploratory</span> data analysis** <span style="color: red"><code>EDA</code></span>

# %%
def save_fig(fig, file_name):
    
    fig.write_image(f"../plots/{file_name}.svg", engine= "orca")
    fig.write_image(f"plots/svg/{file_name}.svg", engine= "orca")
    fig.write_json(f"plots/json/{file_name}.json", engine= "orca")

# %% [markdown]
# #### *Correlation analysis for the features*

# %% [markdown]
# We will drop the ouliers from these the data frames with z-xcore methode<br>
# so we better understand the plot *(we will copy it from the last section.)*

# %%
from functions import tucky_method
from functions import z_score
# with open('functions/tucky.pickle', 'rb') as f:
#     tucky_method = pickle.load(f)

# with open('functions/z-score.pickle', 'rb') as f:
#     z_score = pickle.load(f)


outliers = z_score(base_videos["viewCount"].to_numpy())
outliers_indexes = np.array(*np.where(np.isin(base_videos["viewCount"], outliers)))
temp_base_videos = base_videos.drop(outliers_indexes)

fig = px.scatter(temp_base_videos, x='viewCount', y='likeCount', 
                 size= "commentCount", hover_name="title",
                 color_discrete_sequence= [THEME_COLORS[1]], 
                 labels= {
                          "likeCount": "Video likes",
                          "viewCount": "Video views"},
                 title= "<span style='color: red'>Correlation </span>" + \
                 "between likes, views and comments counts.<br><sup>*The size represents the comments count",
                 width=1100, height=450, opacity= 0.85)

fig.update_xaxes(
    linecolor='black',
    gridcolor='darkgrey')

fig.update_yaxes(
    linecolor='black',
    gridcolor='darkgrey')

fig.update_layout(
    font_family= "Franklin Gothic",
    hovermode='closest')

save_fig(fig, "likes_vs_views_bubble_chart")
iplot(fig)
# Out:
# Found 116 outliers from 19143 length series!
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[46], line 36
#      28 fig.update_yaxes(
#      29     linecolor='black',
#      30     gridcolor='darkgrey')
#      32 fig.update_layout(
#      33     font_family= "Franklin Gothic",
#      34     hovermode='closest')
# ---> 36 save_fig(fig, "likes_vs_views_bubble_chart")
#      37 iplot(fig)
#
# Cell In[45], line 3, in save_fig(fig, file_name)
#       1 def save_fig(fig, file_name):
# ----> 3     fig.write_image(f"../plots/{file_name}.svg", engine= "orca")
#       4     fig.write_image(f"plots/svg/{file_name}.svg", engine= "orca")
#       5     fig.write_json(f"plots/json/{file_name}.json", engine= "orca")
#
# File ~\AppData\Roaming\Python\Python310\site-packages\plotly\basedatatypes.py:3821, in BaseFigure.write_image(self, *args, **kwargs)
#    3761 """
#    3762 Convert a figure to a static image and write it to a file or writeable
#    3763 object
#    (...)
#    3817 None
#    3818 """
#    3819 import plotly.io as pio
# -> 3821 return pio.write_image(self, *args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\plotly\io\_kaleido.py:267, in write_image(fig, file, format, scale, width, height, validate, engine)
#     251             raise ValueError(
#     252                 """
#     253 Cannot infer image type from output path '{file}'.
#    (...)
#     261                 )
#     262             )
#     264     # Request image
#     265     # -------------
#     266     # Do this first so we don't create a file if image conversion fails
# --> 267     img_data = to_image(
#     268         fig,
#     269         format=format,
#     270         scale=scale,
#     271         width=width,
#     272         height=height,
#     273         validate=validate,
#     274         engine=engine,
#     275     )
#     277     # Open file
#     278     # ---------
#     279     if path is None:
#     280         # We previously failed to make sense of `file` as a pathlib object.
#     281         # Attempt to write to `file` as an open file descriptor.
#
# File ~\AppData\Roaming\Python\Python310\site-packages\plotly\io\_kaleido.py:116, in to_image(fig, format, width, height, scale, validate, engine)
#     112 if engine == "orca":
#     113     # Fall back to legacy orca image export path
#     114     from ._orca import to_image as to_image_orca
# --> 116     return to_image_orca(
#     117         fig,
#     118         format=format,
#     119         width=width,
#     120         height=height,
#     121         scale=scale,
#     122         validate=validate,
#     123     )
#     124 elif engine != "kaleido":
#     125     raise ValueError(
#     126         "Invalid image export engine specified: {engine}".format(
#     127             engine=repr(engine)
#     128         )
#     129     )
#
# File ~\AppData\Roaming\Python\Python310\site-packages\plotly\io\_orca.py:1539, in to_image(fig, format, width, height, scale, validate)
#    1487 """
#    1488 Convert a figure to a static image bytes string
#    1489
#    (...)
#    1535     The image data
#    1536 """
#    1537 # Make sure orca sever is running
#    1538 # -------------------------------
# -> 1539 ensure_server()
#    1541 # Handle defaults
#    1542 # ---------------
#    1543 # Apply configuration defaults to unspecified arguments
#    1544 if format is None:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\plotly\io\_orca.py:1390, in ensure_server()
#    1387 if not config.server_url:
#    1388     # Validate orca executable only if server_url is not provided
#    1389     if status.state == "unvalidated":
# -> 1390         validate_executable()
#    1391     # Acquire lock to make sure that we keep the properties of orca_state
#    1392     # consistent across threads
#    1393     with orca_lock:
#    1394         # Cancel the current shutdown timer, if any
#
# File ~\AppData\Roaming\Python\Python310\site-packages\plotly\io\_orca.py:1076, in validate_executable()
#    1073     formatted_path = path.replace(os.pathsep, "\n    ")
#    1075     if executable is None:
# -> 1076         raise ValueError(
#    1077             """
#    1078 The orca executable is required to export figures as static images,
#    1079 but it could not be found on the system path.
#    1080
#    1081 Searched for executable '{executable}' on the following path:
#    1082     {formatted_path}
#    1083
#    1084 {instructions}""".format(
#    1085                 executable=config.executable,
#    1086                 formatted_path=formatted_path,
#    1087                 instructions=install_location_instructions,
#    1088             )
#    1089         )
#    1091     # Check if we should run with Xvfb
#    1092     # --------------------------------
#    1093     xvfb_args = [
#    1094         "--auto-servernum",
#    1095         "--server-args",
#    1096         "-screen 0 640x480x24 +extension RANDR +extension GLX",
#    1097         executable,
#    1098     ]
#
# ValueError:
# The orca executable is required to export figures as static images,
# but it could not be found on the system path.
#
# Searched for executable 'orca' on the following path:
#     C:\Users\FreeComp\.conda\envs\youtube_gaming
#     C:\Users\FreeComp\.conda\envs\youtube_gaming\Library\mingw-w64\bin
#     C:\Users\FreeComp\.conda\envs\youtube_gaming\Library\usr\bin
#     C:\Users\FreeComp\.conda\envs\youtube_gaming\Library\bin
#     C:\Users\FreeComp\.conda\envs\youtube_gaming\Scripts
#     C:\Users\FreeComp\.conda\envs\youtube_gaming\bin
#     C:\ProgramData\miniconda3\condabin
#     C:\Program Files\Common Files\Oracle\Java\javapath
#     C:\Python311\Scripts
#     C:\Python311
#     C:\Windows\system32
#     C:\Windows
#     C:\Windows\System32\Wbem
#     C:\Windows\System32\WindowsPowerShell\v1.0
#     C:\Windows\System32\OpenSSH
#     C:\Program Files (x86)\NVIDIA Corporation\PhysX\Common
#     C:\Program Files\Git\cmd
#     C:\Program Files\nodejs
#     C:\ProgramData\chocolatey\bin
#     C:\Users\FreeComp\AppData\Local\Programs\Python\Python310\Scripts
#     C:\Users\FreeComp\AppData\Local\Programs\Python\Python310
#     C:\Users\FreeComp\AppData\Local\Microsoft\WindowsApps
#     C:\Users\FreeComp\AppData\Local\Programs\Microsoft VS Code\bin
#     C:\Users\FreeComp\AppData\Local\GitHubDesktop\bin
#     C:\Users\FreeComp\AppData\Local\Programs\Julia-1.8.5\bin
#     C:\Users\FreeComp\AppData\Roaming\npm
#     C:\MinGW\bin
#     C:\Program Files\heroku\bin
#
# If you haven't installed orca yet, you can do so using conda as follows:
#
#     $ conda install -c plotly plotly-orca
#
# Alternatively, see other installation methods in the orca project README at
# https://github.com/plotly/orca
#
# After installation is complete, no further configuration should be needed.
#
# If you have installed orca, then for some reason plotly.py was unable to
# locate it. In this case, set the `plotly.io.orca.config.executable`
# property to the full path of your orca executable. For example:
#
#     >>> plotly.io.orca.config.executable = '/path/to/orca'
#
# After updating this executable property, try the export operation again.
# If it is successful then you may want to save this configuration so that it
# will be applied automatically in future sessions. You can do this as follows:
#
#     >>> plotly.io.orca.config.save()
#
# If you're still having trouble, feel free to ask for help on the forums at
# https://community.plot.ly/c/api/python

# %%
plotly.__version__
# Out:
# '5.14.1'

# %%
# !conda install -c plotly plotly-orca

# %%
outliers = tucky_method(base_channels["subscribers"].to_numpy())
outliers_indexes = np.array(*np.where(np.isin(base_channels["subscribers"], outliers)))
temp_base_channels = base_channels.drop(outliers_indexes)

fig = px.scatter(temp_base_channels, x= 'video_count', y= 'avg_views_count', 
                 hover_name= "channel_name", size= "subscribers",
                 color_discrete_sequence= [THEME_COLORS[0]], 
                 labels= {
                          "avg_views_count": "Avg Views per videos",
                          "video_count": "Channel's total videos"},
                 title= "Correlation between Channel's total videos count and Avg views count per video<br>" + \
                 "<sup>*The size represents the subscribers count",
                 width= 800, height= 450, opacity= 0.85)

fig.update_xaxes(
    linecolor='black',
    gridcolor='darkgrey')

fig.update_yaxes(
    linecolor='black',
    gridcolor='darkgrey')

fig.update_layout(
    font_family= "Franklin Gothic",
    hovermode='closest')

save_fig(fig, "tot_videos_vs_avg_views_bubble_chart")
iplot(fig)

# %%
outliers = tucky_method(base_videos["duration_in_minutes"].astype(float).to_numpy())
outliers_indexes = np.array(*np.where(np.isin(base_videos["duration_in_minutes"], outliers)))
temp_base_videos = base_videos.drop(outliers_indexes)

fig = px.scatter(temp_base_videos, x= 'duration_in_minutes', y= 'viewCount', 
                 hover_name= "title", color_discrete_sequence= [THEME_COLORS[0]],
                 labels= {
                          "viewCount": "Views",
                          "duration_in_minutes": "Video duration in minutes"},
                 title= "Correlation between duration in minutes & Views<br>" + \
                 "<sub>",
                 trendline_color_override = THEME_COLORS[1],
                 width= 800, height= 550, opacity= 0.65, trendline= "ols")

fig.update_xaxes(
    linecolor='black',
    gridcolor='darkgrey')

fig.update_yaxes(
    linecolor='black',
    gridcolor='darkgrey')

fig.update_layout(
    font_family= "Franklin Gothic",
    hovermode='closest')

save_fig(fig, "desc_len_vs_views_scatter_plot")
iplot(fig)

# %%
outliers = z_score(base_channels["subscribers"].astype(float).to_numpy())
outliers_indexes = np.array(*np.where(np.isin(base_channels["subscribers"], outliers)))
temp_base_channels = base_channels.drop(outliers_indexes)

temp_base_channels = temp_base_channels.groupby("channel_name_length")["subscribers"].mean().reset_index()

fig = px.line(temp_base_channels, x= "channel_name_length", y= "subscribers", markers=True,
              line_dash_sequence= ["dot"], color_discrete_sequence= [THEME_COLORS[1]])


fig.update_xaxes(
    linecolor='black',
    gridcolor='darkgrey')

fig.update_yaxes(
    linecolor='black',
    gridcolor='darkgrey')

fig.update_layout(
    font_family= "Franklin Gothic",
    hovermode= "closest",
    title= "Relationship between channel name length and" + \
           " it's <span style='color: red'>popularity</span>")


save_fig(fig, "subs_vs_channel_name_len_line_chart")
iplot(fig)

# %%
outliers = z_score(base_channels["subscribers"].astype(float).to_numpy())
outliers_indexes = np.array(*np.where(np.isin(base_channels["subscribers"], outliers)))
temp_base_channels = base_channels.drop(outliers_indexes)


fig = px.scatter_matrix(temp_base_channels, base_channels.select_dtypes(include=NUMERICS).columns,
                        width= 1200, height= 1200, color_discrete_sequence= [THEME_COLORS[1]],
                        hover_name= "channel_name", opacity= 0.5)

fig.update_layout(
    font_family= "Franklin Gothic",
    hovermode= "closest",
    title= "<span style='color: red'>Scatter </span>" + \
           "matrix for channels stats correlations")


save_fig(fig, "vids_data_scatter_matrix")
iplot(fig)

# %%
outliers = z_score(base_videos["viewCount"].to_numpy())
outliers_indexes = np.array(*np.where(np.isin(base_videos["viewCount"], outliers)))
temp_base_videos = base_videos.drop(outliers_indexes)


fig = px.scatter_matrix(temp_base_videos, base_videos.select_dtypes(include=NUMERICS).columns,
                        width= 1000, height= 900, color_discrete_sequence= [THEME_COLORS[0]],
                        hover_name= "title", opacity= 0.4)

fig.update_layout(
    font_family= "Franklin Gothic",
    hovermode= "closest",
    title= "<span style='color: red'>Scatter </span>" + \
           "matrix for videos stats correlations")

save_fig(fig, "channels_data_scatter_matrix")
iplot(fig)

# %% [markdown]
# ##### **Conclusions for this part:**
# - Like counts have **positive** relation-ship with  views count but not as it's correlation<br>
# with comments count and views effect is not very strong on likes & comments.<br><br>
# - Avg channel views affect very strongly on it's subscribers but the **videos counts** have<br>
# **logarithmic** correlation with the subscribers and the sweet spot of it is: $400\sim1200$<br><br>
# - The **long videos** in gaming are **more** popular than **short** ones and the videos that are <br>longer
# than $15$ minutes starts to get lower views<br><br>
# - There are very low videos count between $8$ minutes and $1$ minute becuase Youtube <br>**don't give
# money** for videos in this range.<br><br>
# - The channels that has more chars in it's name than $25$ or less than $8$ are very easy to forget so<br>
# they aren't so popular<br><br>
#
# - At least you should upload more than $2$ videos a month to start getting more subscribers.

# %% [markdown]
# #### *Analysis for categorical varibels*

# %%
tags_dict = {"Tags": [], "Views": [], "Comments": [], "Likes": [],
             "Count": []}
total_views = []
all_tags_temp = base_videos["tags"].explode().explode().tolist()

for tags_chunk in all_tags_temp:
    
    for tag, views, comments, likes in zip(ast.literal_eval(tags_chunk), base_videos["viewCount"],
                                           base_videos["commentCount"], base_videos["likeCount"]):

        tags_dict["Tags"].append(tag)
        tags_dict["Views"].append(views)
        tags_dict["Comments"].append(comments)
        tags_dict["Likes"].append(likes)
        tags_dict["Count"].append(1)
    
tags_df = pd.DataFrame({"Tag": tags_dict["Tags"],
                        "Views": tags_dict["Views"],
                        "Comments count": tags_dict["Comments"],
                        "Likes": tags_dict["Likes"],
                        "Count": tags_dict["Count"]}).groupby('Tag').sum().astype({
    "Views": np.uint32,
    "Comments count": np.uint16,
    "Count": np.uint16,
    "Likes": np.uint32})

# Set the column tag again after we turned it into index
tags_df["Tag"] = tags_df.index

# %%
top_20_tags = tags_df.sort_values(by= "Count", ascending= False).head(20)

fig = px.bar(top_20_tags, x= "Tag", y= "Count", 
             color_discrete_sequence= [THEME_COLORS[1]])

fig.update_layout(
    font_family= "Franklin Gothic",
    hovermode= "closest",
    title= "Tags appending count")

fig.add_annotation(
    text = ("We can find that the shorts in gaming now are more <br>" + \
            "popular now than lives."),
    showarrow= True,
    x = 15,
    y = 500,
    arrowhead=1,
    arrowsize=1,
    arrowwidth=2)

fig.add_annotation(
    text = ("Looks like people looks<br> for gameplay videos<br>" + \
            "more than funny ones."),
    x = 3,
    y = 950,
    showarrow= False)

fig.update_xaxes(
    linecolor='black',
    gridcolor='darkgrey')

fig.update_yaxes(
    linecolor='black',
    gridcolor='darkgrey')

save_fig(fig, "tags_appendings_per_vid_bar_chart")
iplot(fig)

# %%
top_30_tags = tags_df.sort_values(by= "Count", ascending= False).head(30)


fig = go.Figure(data= [go.Bar(name= 'Views',
    x = top_30_tags["Tag"],
    y = top_30_tags["Views"],
    marker={'color': THEME_COLORS[0]}),
                       
        go.Bar(name= 'Likes',
               
    x = top_30_tags["Tag"],
    y = top_30_tags["Likes"],
    marker={'color': THEME_COLORS[1]}),
                      
        go.Bar(name= 'Comments',
               
    x = top_30_tags["Tag"],
    y = top_30_tags["Comments count"],
    marker= {"color": "lightgrey"})], layout= {
    
        "xaxis_title": "Tags",
        "yaxis_title": "Views, Likes & Comments"})

fig.add_annotation(
    text = ("We can find that the shorts in gaming now are more <br>" + \
            "popular now than lives."),
    showarrow= True,
    x = 15,
    y = 50_000_000,
    arrowhead=1,
    arrowsize=1,
    arrowwidth=2)

fig.add_annotation(
    text = ("Looks like people looks for game<br> play videos" + \
            "more than funny ones."),
    x = 5,
    y = 100_000_000,
    showarrow= False)

fig.update_xaxes(
    linecolor='black',
    gridcolor='darkgrey')

fig.update_yaxes(
    linecolor='black',
    gridcolor='darkgrey')

fig.update_layout(
    font_family= "Franklin Gothic",
    hovermode= "closest",
    title= "Views, Likes & comments per Tag")

save_fig(fig, "video_stats_per_tag")
fig.update_layout(barmode='stack')
iplot(fig)

# %%
outliers = z_score(base_videos["viewCount"].to_numpy())
outliers_indexes = np.array(*np.where(np.isin(base_videos["viewCount"], outliers)))
temp_base_videos = base_videos.drop(outliers_indexes)

fig = sp.make_subplots(rows=4, cols=1)

# Add charts to subplots
boolean_cols = ["have_twitter_account", "have_facebook_account",
                "have_twitch_account", "have_instgram_account"]

for i, col in enumerate(boolean_cols):
    
    data = temp_base_videos.groupby(col)["viewCount"].mean().reset_index()
    
    fig.add_trace(
        go.Bar(x= data[col], y= data["viewCount"], marker=dict(color=THEME_COLORS)),
        row= i+1, col= 1)

    fig.update_traces(
        name= col.replace("_", " "),
        row= i+1,
        col= 1,
        showlegend= False)
    
    fig.update_xaxes(
        title= col.replace("_", " ").title(),
        linecolor='black',
        gridcolor='darkgrey',
        row= i+1,
        col= 1)

    fig.update_layout(
    title= "Visualizing social media accounts effect on the youtuber<br>" + \
           "popularity",
    font_family='Franklin Gothic',
    height= 1200, width= 700)


fig.update_yaxes(
    title= 'View count',
    linecolor='black',
    gridcolor='darkgrey')

save_fig(fig, "social_accounts_affect_on_vid_stats")
iplot(fig)

# %%
fig = sp.make_subplots(rows=2, cols=2,
                       specs=[[{'type': 'pie'}, {'type': 'pie'}],
                              [{'type': 'pie'}, {'type': 'pie'}]])

# Add charts to subplots
boolean_cols = ["have_twitter_account", "have_facebook_account",
                "have_twitch_account", "have_instgram_account"]

for i, col in enumerate(boolean_cols[:4]):
    
    data = base_videos.groupby(col)["video_id"].count().reset_index()
    
    fig.add_trace(
        go.Pie(labels=data[col], values=data["video_id"], marker=dict(colors=THEME_COLORS,
                                                                       line=dict(color='white', width=1)),
               title=f'How Many Videos <br>{col.replace("_", " ").title()}'),
        row=i//2+1, col=i%2+1)

    fig.update_traces(
        name=col.replace("_", " "),
        hoverinfo='label+percent',
        textinfo='value',
        row=i//2+1,
        col=i%2+1)

fig.update_layout(
    title="Visualizing How many videos have" + \
           "<span style='color: red'> Social media </span> accounts",
    font_family='Franklin Gothic',
        width=900,
        height=700,)

save_fig(fig, "youtubers_count_with_social_accounts")
iplot(fig)

# %%
outliers = tucky_method(base_games["viewCount"].to_numpy())
outliers_indexes = np.array(*np.where(np.isin(base_games["viewCount"], outliers)))
temp_base_games = base_games.drop(outliers_indexes)


grouped_games = temp_base_games.groupby("game")[["viewCount", "likeCount",
                                            "commentCount"]].mean().reset_index().sort_values(
                                             by= "likeCount", ascending= False)


fig = go.Figure(data= [go.Bar(name= 'Views',
    x = grouped_games["game"],
    y = grouped_games["viewCount"],
    marker={'color': THEME_COLORS[0]}),
                       
        go.Bar(name= 'Likes',
               
    x = grouped_games["game"],
    y = grouped_games["likeCount"],
    marker={'color': THEME_COLORS[1]}),
                      
        go.Bar(name= 'Comments',
               
    x = grouped_games["game"],
    y = grouped_games["commentCount"],
    marker={'color': "lightgrey"})], layout= {
    
        "xaxis_title": "Games",
        "yaxis_title": "Mean of views, Likes & Comments"})

fig.update_xaxes(
    linecolor='black',
    gridcolor='darkgrey')

fig.update_yaxes(
    linecolor='black',
    gridcolor='darkgrey')

fig.update_layout(
    font_family= "Franklin Gothic",
    hovermode= "closest",
    width=1000,
    height=500,
    title= "Views, Likes & comments per <span style='color: red'>Game</span><br>" + \
           "<sub>*The games are sorted from right to left by likes count.")


save_fig(fig, "video_stats_per_game")
fig.update_layout(barmode='group')
iplot(fig)

# %% [markdown]
# ##### **Conclusions for this part:**
# - We can find that channels makes game play videos more than funny & memes videos<br>
# becuase **people watches gameplay videos more** thought **funny videos get more likes**.<br><br>
# - The new Youtube "shorts videos" now get's more likes, views, comments **than lives** but<br>
#  still doesn't beat ordinary gaming videos.<br><br>
# - Having social media accounts can affect on your channel stats positivly about $35\%$ and<br>
# having **Instegram** account is the most popular account that gamers use <sub>*(beside Youtube)</sub>.<br><br>
# - Having **Twitch** account may **not leed** you to be succesful at **Youtube** gaming becuase<br>
# having **Twitch** account leads you to be $66\%$ <ins>**less**</ins> than who don't have one.<br><br>
# - The **top 3** games in views are: (GTA V, Minecraft, and Among us) but Roblox is the **top 1**<br>
# in comments then comes Minecraft.
#
# - Minecraft has $16\%$ higher like per view rate than GTA V

# %% [markdown]
# #### *Geographic analysis*

# %%
geographic_df = pd.merge(stacked_channels, base_channels, on= "channel_name",
                         suffixes= ["", "_"])

geographic_df.drop(["video_count_", "total_views_", "subscribers_"], inplace= True,
                   axis= 1)


outliers = tucky_method(geographic_df["subscribers"].to_numpy())
outliers_indexes = np.array(*np.where(np.isin(geographic_df["subscribers"], outliers)))
geographic_df = geographic_df.drop(outliers_indexes)

alpha2_codes = geographic_df['country'].unique().tolist()
alpha3_codes = []

for code in alpha2_codes:
    try:
        country = pycountry.countries.get(alpha_2=code)
        alpha3_codes.append(country.alpha_3)
    except AttributeError:
        alpha3_codes.append(None)

geographic_df['country'] = geographic_df['country'].cat.remove_unused_categories()
geographic_df['country'] = geographic_df['country'].apply(lambda x: alpha3_codes[alpha2_codes.index(x)])

geographic_df = geographic_df.drop(geographic_df[geographic_df.country == "N/A"].index).groupby(
    by=["country",
        "Collecting date"])[["subscribers", "video_count",
                             "total_views", "avg_like_count"]].mean().reset_index()

geographic_df['Collecting date'] = geographic_df['Collecting date'].apply(lambda x: str(x))

fig = px.choropleth(geographic_df, locations= "country",
                    animation_frame= "Collecting date",
                    color= "subscribers",
                    hover_name= "country",
                    color_continuous_scale= "Reds",
                    projection= "natural earth",
                    range_color=[geographic_df['subscribers'].min(),
                                 geographic_df['subscribers'].max()],
                    title="Subscribers mean per country")

fig.update_layout(
    font_family= "Franklin Gothic",
    hovermode= "closest",
    width=700,
    height=500,
    title= "<span style='color: red'>Subscribers</span> mean per country.")


save_fig(fig, "channels_subs_per_country")
iplot(fig)

# %%
fig = px.scatter_geo(geographic_df, locations="country",
                     hover_name="country", size="avg_like_count",
                     projection= "kavrayskiy7",
                     animation_frame= "Collecting date",
                     color_discrete_sequence= [THEME_COLORS[1]],
                     opacity= 0.8)

fig.update_layout(
    font_family= "Franklin Gothic",
    hovermode= "closest",
    width=700,
    height=500,
    title= "Videos <span style='color: red'>quality</span> mean per country<br>"+\
           "<sub>*The videos quality are measured with average like count</sub><br>")

save_fig(fig, "videos_like_per_country")
iplot(fig)

# %% [markdown]
# ##### **Conclusions for this section**:
# - The highest subscribers for channels mean for a country <sub>*(without low values)</sub> Is **Saudi Arabia** for <br>
# a viewer in my geolocation <br><br>
# - **Brasilia** makes the highest videos in likes even more than Saudi Arabia.<br><br>
# - **Asia** have very high growing rate for channels subscribers more than other continents.

# %% [markdown]
# #### *Time series analysis*

# %%
time_df = stacked_channels.copy()

outliers = tucky_method(time_df["subscribers"].to_numpy())
outliers_indexes = np.array(*np.where(np.isin(time_df["subscribers"], outliers)))
time_df = time_df.drop(outliers_indexes)


unique_vals = pd.Series(time_df["channel_name"].unique()) .sample(10, replace=False,
                                                                 random_state= 1).tolist()
time_df = time_df[time_df["channel_name"].isin(unique_vals)]


fig = px.line(time_df, x= "Collecting date", y= "subscribers",
              color= "channel_name", color_discrete_sequence= px.colors.sequential.Reds)


fig.update_layout(
    font_family= "Franklin Gothic",
    hovermode= "closest",
    width=1000,
    height=400,
    title= "Channels subscribers growth per time.<br>"+\
           "<sub>*Youtube API down cast subscribers count</sub><br>")

fig.update_xaxes(
    linecolor='black',
    gridcolor='darkgrey')

fig.update_yaxes(
    linecolor='black',
    gridcolor='darkgrey')

save_fig(fig, "channels_subs_growth_per_time")
iplot(fig)

# %%
time_df = base_channels.copy()

outliers = tucky_method(time_df["subscribers"].to_numpy())
outliers_indexes = np.array(*np.where(np.isin(time_df["subscribers"], outliers)))
time_df = time_df.drop(outliers_indexes)

time_df["date"] = pd.to_datetime(time_df["date"].dt.strftime('%Y-%m'))

time_df = time_df.groupby("date")[time_df.select_dtypes(
    NUMERICS).columns].sum().reset_index()


fig = px.bar(time_df, x= 'date', y= "subscribers", hover_name= "subscribers",
             color_discrete_sequence= [THEME_COLORS[1]], opacity= 0.8)


fig.update_layout(
    font_family= "Franklin Gothic",
    hovermode= "closest",
    width=1000,
    height=400,
    title= "Total of Susbcribers compared to time<br><sub>" + \
           "* the data represents the total subscribers for all channels found in a time period")

fig.update_xaxes(
    linecolor='black',
    gridcolor='darkgrey')

fig.update_yaxes(
    linecolor='black',
    gridcolor='darkgrey')


save_fig(fig, "total_subs_for_channels_per_start_date")
iplot(fig)

# %%
time_df = base_videos.copy()

outliers = tucky_method(time_df["viewCount"].to_numpy())
outliers_indexes = np.array(*np.where(np.isin(time_df["viewCount"], outliers)))
time_df = time_df.drop(outliers_indexes)

time_df["publishedAt"] = pd.to_datetime(time_df["publishedAt"].dt.strftime('%Y-%m'))

time_df = time_df.groupby("publishedAt")[time_df.select_dtypes(
    NUMERICS).columns].mean().reset_index()

time_df["likeCount"] = time_df["likeCount"] * 10
time_df["commentCount"] = time_df["commentCount"] * 20

fig = go.Figure()

fig.add_trace(go.Line(x= time_df["publishedAt"], y= time_df["likeCount"],
                      name= "Likes change per time", 
                      line = dict(color= THEME_COLORS[0], width= 3, dash= 'dot')))

fig.add_trace(go.Line(x= time_df["publishedAt"], y= time_df["viewCount"],
                      name= "Views change per time", 
                      line = dict(color= THEME_COLORS[1], width= 3, dash= 'dot')))

fig.add_trace(go.Line(x= time_df["publishedAt"], y= time_df["commentCount"],
                      name= "Comments change per time", 
                      line = dict(color= "lightgrey", width= 3, dash= 'dot')))

fig.update_layout(
    font_family= "Franklin Gothic",
    hovermode= "closest",
    width=1000,
    height=400,
    title= "<span style='color: red'>Change</span> in likes and views per time<br><sub>" + \
           "*like counts are scaled by 10 to be readable & comments are scaled by 20")

fig.update_xaxes(
    linecolor='black',
    gridcolor='darkgrey')

fig.update_yaxes(
    linecolor='black',
    gridcolor='darkgrey')

save_fig(fig, "video_stats_growth_per_time")
iplot(fig)

# %% [markdown]
# ## <center> **<span style="color: red">Final</span> Conclusions** <span style="color: red"></span>
