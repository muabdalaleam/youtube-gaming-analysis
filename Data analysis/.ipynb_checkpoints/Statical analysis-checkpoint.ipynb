# %% [markdown]
# ## <center> **Importing the <span style="color: red">Packeges</span>**

# %%
import pandas as pd
import numpy as np
import matplotlib
import seaborn as sns
import panel as pn
from scipy import stats
import sqlite3
import pickle
from numba import jit

from IPython.display import set_matplotlib_formats
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
THEME_COLORS = ["#383838", "#ff0000"]

set_matplotlib_formats('pdf', 'svg')
# Out:
# C:\Users\FreeComp\AppData\Local\Temp\ipykernel_11388\2255309837.py:4: DeprecationWarning: `set_matplotlib_formats` is deprecated since IPython 7.23, directly use `matplotlib_inline.backend_inline.set_matplotlib_formats()`
#   set_matplotlib_formats('pdf', 'svg')

# %%
THEME_COLORS = ["#383838", "#ff0000"]
NUMERICS = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
FONT = 13

# %% [markdown]
# ## <center> **Reading and simple <span style="color: red">exploring</span>**

# %%
con = sqlite3.connect('../database.db')

df = pd.read_sql_query("""-- The outuput of this querry will be assigned to
                          -- `df` variable.

                          SELECT *
                          FROM base_videos
                          INNER JOIN base_channels ON
                          channelTitle = channel_name""", con)

con.close()

# %% [markdown]
# This data frame is a temporary combination for this notebook only to explore the statics for<br>
# our data.

# %%
df.sample(5)
# Out:
#           video_id               channelTitle
# 15415  Kdz-unTiHO4  Gamer's Little Playground  \
# 4705   LKbaT9e1zdA               ERWIN GAMING
# 2852   0GkMscOxpnM                  VY Gaming
# 19086  ZoGVvu8A2DA             Jenders Gaming
# 6451   7xCaXaz6-bY            Features Gaming
#
#                                                    title
# 15415  Resident Evil 4 Remake - Osmund Saddler Final ...  \
# 4705   အမွှေစိန်လေးကို ကလေးထိန်းမယ်🤣😂The baby in Yell...
# 2852   HERO PREMIUM DI BUFF MOONTON?!? UNLIMITED SKIL...
# 19086  Mindbug is a 2-player game where you go head t...
# 6451   FLYING THE PLANE IN CABIN CREW SIMULATOR - NEW...
#
#                                              description
# 15415  Resident Evil 4 Remake - Osmund Saddler Final ...  \
# 4705   The Baby In Yellow\nThe baby in yellow Gamepla...
# 2852   sesuai dengan request kalian di kolom komentar...
# 19086                     #shortsfeed #shorts #fypシ #fyp
# 6451   FLYING THE PLANE IN CABIN CREW SIMULATOR - NEW...
#
#                                                     tags
# 15415  ['game', 'full', 'gameplay', 'no commentary', ...  \
# 4705   ['The Baby In Yellow', 'the Baby In Yellow Mya...
# 2852   ['Mobile Legends', 'Mobile Legends: Bang Bang'...
# 19086                           ['mindbug', 'card game']
# 6451   ['Features Gaming', 'featuresgaming', 'cabin c...
#
#                      publishedAt  viewCount  likeCount  commentCount
# 15415  2023-03-24 07:50:49+00:00      64081        766           209  \
# 4705   2023-01-23 08:29:29+00:00      78374       1534           131
# 2852   2023-02-28 00:00:00+00:00     269058       5022          1967
# 19086  2023-04-04 13:34:33+00:00         33          1             0
# 6451   2023-03-26 19:30:00+00:00       3651         91            27
#
#       definition  duration_in_minutes               channel_name  subscribers
# 15415         hd            20.046875  Gamer's Little Playground      2560000  \
# 4705          hd            10.203125               ERWIN GAMING       134000
# 2852          hd            10.929688                  VY Gaming      3810000
# 19086         hd             0.266602             Jenders Gaming         2690
# 6451          hd            27.359375            Features Gaming        15500
#
#        total_views                 date  video_count
# 15415   1308662087  2009-12-29 00:00:00         4852  \
# 4705      28551971  2021-10-17 00:00:00          382
# 2852     905510842  2016-10-04 00:00:00         2892
# 19086       410505  2012-07-15 00:00:00          472
# 6451       4231093  2015-03-29 00:00:00         3182
#
#                                                    about country
# 15415  Stop playing. Start gaming.\n\nHome of the Gam...      US
# 4705                 I like playing games with mods. 😁☺️      SG
# 2852   Welcome to my Channel , Here You can find all ...      ID
# 19086  Welcome to the channel! \nHere it's all about ...      SE
# 6451   Hi YouTubers, my name is Features Gaming!\nHer...      GB

# %%
cm = sns.light_palette(THEME_COLORS[1], as_cmap=True)
df.select_dtypes(NUMERICS).sample(6).style.background_gradient(cmap=cm)
# Out:
# <style type="text/css">
# #T_36c14_row0_col0 {
#   background-color: #fc3d3d;
#   color: #f1f1f1;
# }
# #T_36c14_row0_col1, #T_36c14_row0_col2, #T_36c14_row1_col3, #T_36c14_row2_col6, #T_36c14_row3_col0, #T_36c14_row5_col4, #T_36c14_row5_col5 {
#   background-color: #ff0000;
#   color: #f1f1f1;
# }
# #T_36c14_row0_col3, #T_36c14_row5_col3 {
#   background-color: #f3eeee;
#   color: #000000;
# }
# #T_36c14_row0_col4 {
#   background-color: #ff0909;
#   color: #f1f1f1;
# }
# #T_36c14_row0_col5 {
#   background-color: #f88f8f;
#   color: #000000;
# }
# #T_36c14_row0_col6 {
#   background-color: #f3ecec;
#   color: #000000;
# }
# #T_36c14_row1_col0, #T_36c14_row1_col1, #T_36c14_row1_col2, #T_36c14_row1_col4, #T_36c14_row1_col5, #T_36c14_row3_col6, #T_36c14_row4_col0, #T_36c14_row4_col1, #T_36c14_row4_col2, #T_36c14_row4_col3 {
#   background-color: #f3f0f0;
#   color: #000000;
# }
# #T_36c14_row1_col6 {
#   background-color: #f89090;
#   color: #000000;
# }
# #T_36c14_row2_col0, #T_36c14_row3_col2 {
#   background-color: #f3ebeb;
#   color: #000000;
# }
# #T_36c14_row2_col1, #T_36c14_row2_col2, #T_36c14_row2_col3 {
#   background-color: #f3eded;
#   color: #000000;
# }
# #T_36c14_row2_col4 {
#   background-color: #fa6767;
#   color: #f1f1f1;
# }
# #T_36c14_row2_col5 {
#   background-color: #f97a7a;
#   color: #f1f1f1;
# }
# #T_36c14_row3_col1 {
#   background-color: #f89494;
#   color: #000000;
# }
# #T_36c14_row3_col3 {
#   background-color: #f3efef;
#   color: #000000;
# }
# #T_36c14_row3_col4, #T_36c14_row5_col6 {
#   background-color: #f4d2d2;
#   color: #000000;
# }
# #T_36c14_row3_col5 {
#   background-color: #f4dcdc;
#   color: #000000;
# }
# #T_36c14_row4_col4 {
#   background-color: #f7a5a5;
#   color: #000000;
# }
# #T_36c14_row4_col5 {
#   background-color: #f6b8b8;
#   color: #000000;
# }
# #T_36c14_row4_col6 {
#   background-color: #f97b7b;
#   color: #f1f1f1;
# }
# #T_36c14_row5_col0 {
#   background-color: #fa6868;
#   color: #f1f1f1;
# }
# #T_36c14_row5_col1 {
#   background-color: #f97979;
#   color: #f1f1f1;
# }
# #T_36c14_row5_col2 {
#   background-color: #fc3f3f;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_36c14">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_36c14_level0_col0" class="col_heading level0 col0" >viewCount</th>
#       <th id="T_36c14_level0_col1" class="col_heading level0 col1" >likeCount</th>
#       <th id="T_36c14_level0_col2" class="col_heading level0 col2" >commentCount</th>
#       <th id="T_36c14_level0_col3" class="col_heading level0 col3" >duration_in_minutes</th>
#       <th id="T_36c14_level0_col4" class="col_heading level0 col4" >subscribers</th>
#       <th id="T_36c14_level0_col5" class="col_heading level0 col5" >total_views</th>
#       <th id="T_36c14_level0_col6" class="col_heading level0 col6" >video_count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_
td>
#     </tr>
#   </tbody>
# </table>

# %%
cm = sns.light_palette(THEME_COLORS[1], as_cmap=True)
df.describe().style.background_gradient(cmap=cm)
# Out:
# <style type="text/css">
# #T_806b3_row0_col0, #T_806b3_row0_col4, #T_806b3_row0_col5, #T_806b3_row1_col0, #T_806b3_row1_col3, #T_806b3_row3_col0, #T_806b3_row3_col1, #T_806b3_row3_col2, #T_806b3_row3_col3, #T_806b3_row3_col4, #T_806b3_row3_col5, #T_806b3_row3_col6, #T_806b3_row4_col0, #T_806b3_row4_col1, #T_806b3_row4_col2, #T_806b3_row4_col3, #T_806b3_row4_col4, #T_806b3_row4_col5, #T_806b3_row5_col0, #T_806b3_row5_col1, #T_806b3_row5_col2, #T_806b3_row5_col3, #T_806b3_row6_col0, #T_806b3_row6_col1, #T_806b3_row6_col3 {
#   background-color: #f3f0f0;
#   color: #000000;
# }
# #T_806b3_row0_col1, #T_806b3_row5_col5 {
#   background-color: #f3eeee;
#   color: #000000;
# }
# #T_806b3_row0_col2 {
#   background-color: #f79f9f;
#   color: #000000;
# }
# #T_806b3_row0_col3, #T_806b3_row0_col6, #T_806b3_row7_col0, #T_806b3_row7_col1, #T_806b3_row7_col2, #T_806b3_row7_col4, #T_806b3_row7_col5 {
#   background-color: #ff0000;
#   color: #f1f1f1;
# }
# #T_806b3_row1_col1, #T_806b3_row1_col2, #T_806b3_row2_col3, #T_806b3_row5_col4, #T_806b3_row6_col2 {
#   background-color: #f3efef;
#   color: #000000;
# }
# #T_806b3_row1_col4, #T_806b3_row2_col2, #T_806b3_row6_col5 {
#   background-color: #f3e8e8;
#   color: #000000;
# }
# #T_806b3_row1_col5 {
#   background-color: #f3e6e6;
#   color: #000000;
# }
# #T_806b3_row1_col6 {
#   background-color: #f3e4e4;
#   color: #000000;
# }
# #T_806b3_row2_col0 {
#   background-color: #f3ebeb;
#   color: #000000;
# }
# #T_806b3_row2_col1 {
#   background-color: #f3e8e7;
#   color: #000000;
# }
# #T_806b3_row2_col4 {
#   background-color: #f4dada;
#   color: #000000;
# }
# #T_806b3_row2_col5 {
#   background-color: #f4d5d5;
#   color: #000000;
# }
# #T_806b3_row2_col6 {
#   background-color: #f4e2e2;
#   color: #000000;
# }
# #T_806b3_row4_col6 {
#   background-color: #f3eded;
#   color: #000000;
# }
# #T_806b3_row5_col6 {
#   background-color: #f3e9e9;
#   color: #000000;
# }
# #T_806b3_row6_col4 {
#   background-color: #f3eaea;
#   color: #000000;
# }
# #T_806b3_row6_col6 {
#   background-color: #f4e1e1;
#   color: #000000;
# }
# #T_806b3_row7_col3 {
#   background-color: #f4d8d8;
#   color: #000000;
# }
# #T_806b3_row7_col6 {
#   background-color: #f79897;
#   color: #000000;
# }
# </style>
# <table id="T_806b3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_806b3_level0_col0" class="col_heading level0 col0" >viewCount</th>
#       <th id="T_806b3_level0_col1" class="col_heading level0 col1" >likeCount</th>
#       <th id="T_806b3_level0_col2" class="col_heading level0 col2" >commentCount</th>
#       <th id="T_806b3_level0_col3" class="col_heading level0 col3" >duration_in_minutes</th>
#       <th id="T_806b3_level0_col4" class="col_heading level0 col4" >subscribers</th>
#       <th id="T_806b3_level0_col5" class="col_heading level0 col5" >total_views</th>
#       <th id="T_806b3_level0_col6" class="col_heading level0 col6" >video_count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T
level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_806b3_row6_col0" class="data row6 col0" >136209.000000</td>
#       <td id="T_806b3_row6_col1" class="data row6 col1" >5815.500000</td>
#       <td id="T_806b3_row6_col2" class="data row6 col2" >260.000000</td>
#       <td id="T_806b3_row6_col3" class="data row6 col3" >31.640625</td>
#       <td id="T_806b3_row6_col4" class="data row6 col4" >863000.000000</td>
#       <td id="T_806b3_row6_col5" class="data row6 col5" >189310658.000000</td>
#       <td id="T_806b3_row6_col6" class="data row6 col6" >1263.000000</td>
#     </tr>
#     <tr>
#       <th id="T_806b3_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_806b3_row7_col0" class="data row7 col0" >119872567.000000</td>
#       <td id="T_806b3_row7_col1" class="data row7 col1" >1787829.000000</td>
#       <td id="T_806b3_row7_col2" class="data row7 col2" >57276.000000</td>
#       <td id="T_806b3_row7_col3" class="data row7 col3" >1928.000000</td>
#       <td id="T_806b3_row7_col4" class="data row7 col4" >34700000.000000</td>
#       <td id="T_806b3_row7_col5" class="data row7 col5" >5648937017.000000</td>
#       <td id="T_806b3_row7_col6" class="data row7 col6" >7136.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19343 entries, 0 to 19342
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   video_id             19343 non-null  object
#  1   channelTitle         19343 non-null  object
#  2   title                19343 non-null  object
#  3   description          19343 non-null  object
#  4   tags                 19343 non-null  object
#  5   publishedAt          19343 non-null  object
#  6   viewCount            19343 non-null  int64
#  7   likeCount            19343 non-null  int64
#  8   commentCount         19343 non-null  int64
#  9   definition           19343 non-null  object
#  10  duration_in_minutes  19343 non-null  float64
#  11  channel_name         19343 non-null  object
#  12  subscribers          19343 non-null  int64
#  13  total_views          19343 non-null  int64
#  14  date                 19343 non-null  object
#  15  video_count          19343 non-null  int64
#  16  about                19343 non-null  object
#  17  country              19343 non-null  object
# dtypes: float64(1), int64(6), object(11)
# memory usage: 2.7+ MB

# %%
print(f"The data consumation here is: {df.memory_usage(deep= True).sum() // 1024 ** 2} MB")
# Out:
# The data consumation here is: 83 MB

# %% [markdown]
# Now we just need to convert `date col` & `publishedAt` col into *date-time* ones

# %%
df["publishedAt"] = pd.to_datetime(df["publishedAt"])
df["date"] = pd.to_datetime(df["date"])

# %% [markdown]
# ## <strong><center><span style= "color: red"> Bias </span>& distribution checking

# %% [markdown]
# #### <strong>1-</strong> *Checking for geographic bias*

# %%
explodes = [0.05] * 10

fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(10, 7))

top_10_countries = df.groupby('country').size().sort_values(ascending= False)[:10]
random_countries = df.groupby('country').size().sample(10, random_state= 7)

top_10_countries.plot(kind='pie', textprops={'fontsize': 9},
                      ax= ax1, autopct= '%1.0f%%', explode= explodes,
                      shadow= True, colors= THEME_COLORS)

random_countries.plot(kind='pie', textprops={'fontsize': 9},
                      ax= ax2, autopct= '%1.0f%%', explode= explodes,
                      shadow= True, colors= THEME_COLORS)

ax1.set_title("Top 10 countries appendings")
ax2.set_title("Random 10 countries appendings")

plt.show()

# %% [markdown]
# Looks like there is a bias for my country <ins>(Egypt)</ins> because I use my personal youtube API key<br>
# so youtube algorithm recommends videos from my region when I search for the keyword: <ins><br>
# (Gaming)</ins> But the bias isn't so strong and still the **U.S** and **India** are the highest appending<br>
# ones.

# %% [markdown]
# #### <strong>2-</strong> *Checking for bias in video length*

# %%
sns.displot(df["duration_in_minutes"], color= THEME_COLORS[1])

plt.title("Duration distrbution")
plt.show()

# %% [markdown]
# The data has a lot of outliers so we can't see the data clearly.

# %% [markdown]
# ## <strong><center><span style= "color: red"> Outliers </span> detection

# %% [markdown]
# **Important note**: We will just right the algorithm that we will use and detect the outliers<br>
# (not dropping them) we will just view them and save this function to use later.<br>
# Here we will just view it's performance compared to other algorithms and save the best.

# %% [markdown]
# #### **Hampel filter**

# %% [markdown]
# We will use hampal filter algorithm you can find more [**Here**](https://towardsdatascience.com/outlier-detection-with-hampel-filter-85ddf523c73d) and here's it's theory:<br>
# $H_i = median(|x_j - x_i|): j ∈ [i - k, i + k]$<br>
# where $k$ is a constant usually equalls the scale factor for the gussian distbution<br>
# which equalls $1.4826$

# %%
test_col = df["viewCount"].to_numpy() 
# we will use this column as test for our algorithms performances

# %%
@jit(nopython= True)
def hampel_filter(array: np.array, window_size: int, n_sigmas: int= 3) -> list:
    """
    This function takes an array-like numerical object with
    window size, sigmas count to get the outliers of the
    array
    
    :Params: series: list-like
             window_size: int
             n_sigmas: int (default is 3)
             
    :Returns: indices: list (indexes of the founded outliers)
    """
    
    n: int = len(array)
    K: float = 1.4826
    indices = []
    
    for i in range((window_size),(n - window_size)):
        
        x0 = np.median(array[(i - window_size):(i + window_size)])
        S0 = K * np.median(np.abs(array[(i - window_size):(i + window_size)] - x0))
        
        if (np.abs(array[i] - x0) > n_sigmas * S0):
            indices.append(i)
    
    print(f"Found {len(indices)} outliers from {len(array)} length series!")
    
    return indices

# %%
hampel_indices = hampel_filter(test_col, window_size= 10, n_sigmas= 3)
hampel_outliers = test_col[hampel_indices]
# Out:
# Found 4553 outliers from 19343 length series!

# %%
print(f" The standard deviation of the original column is: {np.std(test_col):.0f}\n",
      f"But now it's {np.std(np.setdiff1d(test_col, hampel_outliers)):.0f}")
# Out:
#  The standard deviation of the original column is: 2711652
#  But now it's 66469

# %% [markdown]
# This means that this algorithm cutted down the STD of the test column into it's half<br>
# with just dropping  less than it's quarter.

# %% [markdown]
# #### **Tucky method**

# %% [markdown]
# Now we will try [**Tucky method**](https://www.google.com) it's strong algorithm so it's not good for limited data<br>
# but we will try it and here's it's theory:<br>
# $Upper\;limit = Q3 + (IQR\times1.5)$<br>
# $Lower\;limit = Q1 - (IQR\times1.5)$<br><br>
# any higher number than Upper limit is dropped and vica versa.

# %%
@jit(nopython= True)
def tucky_method(array: np.array) -> np.array:
    """
    This function works with any list-like numerical object
    (don't work with pandas series's) and returns the indexes
    of the found outliers in the array.
    
    :Params: Takes only the series.
    :Returns: S list of the outliers indexes.
    """
    
    Q3 = np.quantile(array, 0.75)
    Q1 = np.quantile(array, 0.25)
    IQR = Q3 - Q1
    
    upper_range = Q3 + (IQR * 1.5)
    lower_range = Q1 - (IQR * 1.5)
    
    outliers = [x for x in array if ((x < lower_range) | (x > upper_range))]
    print(f"Found {len(outliers)} outliers from {len(array)} length series!")
    
    return outliers

# %%
tucky_outliers = tucky_method(test_col)
tucky_indices = np.array(*np.where(np.isin(test_col, tucky_outliers)))
# Out:
# Found 2523 outliers from 19343 length series!

# %%
print(f" The standard deviation of the original column is: {np.std(test_col):.0f}\n",
      f"But now it's {np.std(np.setdiff1d(test_col, tucky_outliers)):.0f}")
# Out:
#  The standard deviation of the original column is: 2711652
#  But now it's 78766

# %% [markdown]
# #### **$\textbf{Z}$-score method**

# %% [markdown]
# Z-score outlier detection method is very soft method that tries to drop the most<br>
# of the strong outliers only and here's it's theory:<br>
# $Upper\;limit = \mu + (3\times\sigma)$<br>
# $Lower\;limit = \mu - (3\times\sigma)$

# %%
@jit(nopython=True)
def z_score(array) -> np.array:
    """
    This function uses Z-score outlier detection method
    to detect outliers and return them into array.

    :Params: array: list-like numerical object
    :Returns: outliers: np.array (array of the outliers)
    """
    
    std: float = array.std()
    mean: float = array.mean()
    
    upper_limit = mean + (3 * std)
    lower_limit = mean - (3 * std)

    outliers = [value for value in array if 
        (value > upper_limit) | (value < lower_limit)]

    print(f"Found {len(outliers)} outliers from {len(array)} length series!")

    return outliers

# %%
z_score_outliers = z_score(test_col)
z_score_indices = np.array(*np.where(np.isin(test_col, z_score_outliers)))
# Out:
# Found 118 outliers from 19343 length series!

# %%
print(f" The standard deviation of the original column is: {np.std(test_col):.0f}\n",
      f"But now it's {np.std(np.setdiff1d(test_col, z_score_outliers)):.0f}")
# Out:
#  The standard deviation of the original column is: 2711652
#  But now it's 649818

# %% [markdown]
# #### **Visualizing thier performance**

# %%
fig, ax = plt.subplots(1)

ax.plot(test_col, color= THEME_COLORS[0])
ax.scatter(hampel_indices, test_col[hampel_indices], s= 7, c= THEME_COLORS[1])

ax.ticklabel_format(style='plain')

ax.get_yaxis().set_major_formatter(
        matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))

fig.set_size_inches(12, 5)
fig.text(.13, .8, "*The red dots are the detected outliers.\n with the algorithm")

plt.title("Hampel filter performance line chart")
plt.show()

# %%
fig, ax = plt.subplots(1)

ax.plot(test_col, color= THEME_COLORS[0])
ax.scatter(tucky_indices, test_col[tucky_indices], s= 7, c= THEME_COLORS[1])

ax.ticklabel_format(style='plain')

ax.get_yaxis().set_major_formatter(
        matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))

fig.set_size_inches(12, 5)
plt.title("Tucky method performance line chart")
plt.show()

# %%
fig, ax = plt.subplots(1)

ax.plot(test_col, color= THEME_COLORS[0])
ax.scatter(z_score_indices, test_col[z_score_indices], s= 7, c= THEME_COLORS[1])

ax.ticklabel_format(style='plain')

ax.get_yaxis().set_major_formatter(
        matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))

fig.set_size_inches(12, 5)
plt.title("Z-score method performance line chart")
plt.show()

# %% [markdown]
# **Important note**: We can find that we can't choose just one of them so we will choose the best<br>
# two ones becuase we can't predict now how will they perform in the ML phase so we will choose:<br>
# 1. Tucky method
# 2. $\textbf{Z}$-score algorithm
#
# Now we will safe them with **Pickle**

# %%
with open(r"functions/z-score.pickle", "wb") as f:
    pickle.dump(z_score, f)
    
with open(r"functions/tucky.pickle", "wb") as f:
    pickle.dump(tucky_method, f)

# %% [markdown]
# ## <center>**<span style= "color: red"> Correlation </span> test**

# %%
corr = df.corr(numeric_only= True, method= "spearman")
cm = sns.light_palette(THEME_COLORS[1], as_cmap=True)

sns.heatmap(corr, annot=True, fmt=".2f", cmap= cm)
plt.title("Spearman correlation cofficient heatmap")
plt.show()

# %% [markdown]
# **Important note**: Any $p\;value$ aka (the percentages) higher than $0.05$ proofs that the hypothesis between<br>
# the two columns is true so **now we can profe a lot of correlations** but we will conclude thoose in the **EDA<br> phase**
