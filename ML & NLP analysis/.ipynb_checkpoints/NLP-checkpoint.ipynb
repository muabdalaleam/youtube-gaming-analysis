# %% [markdown]
# ## <center> **<span style="color: red">NLP</span> steps and explnation.**

# %% [markdown]
# Here we will use <span style="color: #ffd21e">**Hugging face**</span> trasformers pre trained models becuase it'll take so much effort to label<br>
# all of our text columns "<ins>Comments, Describtion, Title</ins>" and also we will extract categorical and numirecal<br>
# features from the text columns.<br><br>
#
# ##### **Steps in detail:**
# <ul>
#     <li>Extract categorical features from text columns sush as:<ol>
#         <li>Contains emojies
#         <li>Positive or negative
#         <li>Language
#         <li>Video stats range</ol>
#     <li> Doing analysis for most common words in comments and titles (Word cloud)
#     <li> Extracing the length of the comments, descriptions & titles
#     <li> One hot encoding
#     <li> Stemming the data and tokenizing it
#     <li> Saving those new data into new <strong>one</strong> Df to use in the final ML model

# %% [markdown]
# ##### **Important note:**
# The data in this analysis may be a little bit biased becuase all comments is made to be at least more than <br>
# $50$.

# %% [markdown]
# ## <center> **Importing the <span style="color: red">Packeges</span>**<br>

# %%
import re
import os
import ast
import time
import nltk
import emoji
import pickle
import sqlite3
import numpy as np

import pandas as pd
import transformers
from dash import html, callback, Input, Output, register_page, dcc

from PIL import Image
import huggingface_hub
from nltk.corpus import wordnet
import matplotlib.pyplot as plt
from xgboost import XGBClassifier
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from IPython.display import display, Markdown
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report
from IPython.display import set_matplotlib_formats
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

from wordcloud import (WordCloud,
                       STOPWORDS,
                       ImageColorGenerator)

# %%
with open("../Data analysis/functions/z-score.pickle", "rb") as f:
    z_score = pickle.load(f)

# %matplotlib inline
huggingface_hub.notebook_login()
set_matplotlib_formats('pdf', 'svg')
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…
# C:\Users\FreeComp\AppData\Local\Temp\ipykernel_15180\3753516804.py:6: DeprecationWarning: `set_matplotlib_formats` is deprecated since IPython 7.23, directly use `matplotlib_inline.backend_inline.set_matplotlib_formats()`
#   set_matplotlib_formats('pdf', 'svg')

# %% [markdown]
# ## <center> **Reading the <span style="color: red">data</span>**

# %%
TEXT_COLUMNS = ["title", "comments", "description", "channelTitle", "about"]
NUMERICS = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64',
            'uint16', 'uint32', 'uint64', float, int]

con = sqlite3.connect('../database.db')

df = pd.read_sql_query("""

                        SELECT *
                        FROM base_videos AS bv

                        INNER JOIN base_channels  AS bc ON
                            bc.channel_name = bv.channelTitle

                        INNER JOIN comments  AS c ON
                            c.video_id = bv.video_id""", con)

con.close()

df = df.T.drop_duplicates().T # dropping duplicated cols

# %%
df = df.sample(50)

# %% [markdown]
# ##  <center> **Extract <span style="color: red">categorical</span> features**

# %% [markdown]
# #### *Extract emojies count per text*

# %%
comments_emojis_counts: list = []
title_emojis_counts: list = []
desc_emojis_counts: list = []

for comment, title, desc in zip(df["comments"], df["title"], df["description"]):
    
    comments_emojis_count: int = 0
    title_emojis_count: int = 0
    desc_emojis_count: int = 0
    
    for comment_char, title_char, desc_char in zip(comment, title, desc):
        
        if emoji.is_emoji(comment_char):
            comments_emojis_count += 1
            
        if emoji.is_emoji(title_char):
            title_emojis_count += 1
            
        if emoji.is_emoji(desc_char):
            desc_emojis_count += 1
    
    comments_emojis_counts.append(comments_emojis_count)
    title_emojis_counts.append(title_emojis_count)
    desc_emojis_counts.append(desc_emojis_count)

# %%
df["comments_emojis_count"] = comments_emojis_counts
df["title_emojis_count"] = title_emojis_counts
df["desc_emojis_count"] = desc_emojis_counts

df.sample(5)
# Out:
#          video_id       channelTitle  \
# 5244  -eIzwY8HVX0  KairosTime Gaming
# 769   Lgbl1qI6Iak        Sumo Gaming
# 1494  a5dbODAbPVA       MUNNO Gaming
# 619   p5IaCTJdVuM   Gaming Historian
# 909   F2smrp5n1kg    Gaming Gangs HD
#
#                                                   title  \
# 5244           Is Chester WORTH Unlocking & Upgrading?!
# 769     The *RANDOM* SKIN CHALLENGE In Garena Free Fire
# 1494  36 KILLS🔥MY BEST GAMEPLAY | SOLO vs SQUAD | Pu...
# 619   Before Apple: Steve Jobs at Atari | Gaming His...
# 909   eFOOTBALL 2023 vs DLS 22 vs FIFA 22 vs VIVE LE...
#
#                                             description  \
# 5244  How good is Chester & is he worth it?! | Kairo...
# 769   SUB TO BE A LEGEND - https://bit.ly/3A2cBs9\n\...
# 1494  Thanks for watching\nPlease subscribe to  my c...
# 619   New viewer? Subscribe! ► http://goo.gl/WCIhMQ\...
# 909   eFOOTBALL 2023 vs DLS 22 vs FIFA 22 vs VIVE LE...
#
#                                                    tags  \
# 5244  ['Brawl Stars', 'BrawlStars', 'Kairos', 'Kairo...
# 769   ['sumo gaming', 'garena free fire', 'free fire...
# 1494  ['Munno', 'Handcam', 'Pubg', 'Pubg mobile', 'İ...
# 619   ['Steve Jobs', 'Steve Wozniak', 'Nolan Bushnel...
# 909   ['efootball 2023', 'dls 22', 'fifa 22', 'vive ...
#
#                     publishedAt viewCount likeCount commentCount definition  \
# 5244  2022-12-13 14:00:00+00:00    363904     11301         1019         hd
# 769   2022-03-29 05:00:08+00:00   2776845     68285          703         hd
# 1494  2023-03-30 08:13:18+00:00     70108      3187           92         hd
# 619   2017-09-08 16:50:15+00:00    436441     14835         1604         hd
# 909   2022-06-17 09:00:07+00:00   2099244     35367          342         hd
#
#       ...                 date video_count  \
# 5244  ...  2016-07-01 00:00:00        1097
# 769   ...  2019-10-13 00:00:00         223
# 1494  ...  2019-12-01 00:00:00        1803
# 619   ...  2006-07-17 00:00:00         142
# 909   ...  2018-11-27 00:00:00          84
#
#                                                   about country  \
# 5244  I'm KairosTime, and it's TIME to BRAWL! I Frea...      US
# 769   Hello, My name is Sumo.\nThis channel make con...      IN
# 1494  Hey! Subscribe😘\n✅1.000 Subs 19/03/2020\n✅10.0...      US
# 619   The Gaming Historian is a documentary series a...      US
# 909   We are focusing on Quality not Quantity 🥰🥰 \nW...      US
#
#                                                comments like_counts  \
# 5244  I was playing Chester at ~550 earlier and I go...           0
# 769    Red AND BLACK Is OP NOOOOOOOOOOOOOOOOOOOO......B           0
# 1494                                          nice game           0
# 619             virgin Steve Jobs vs Chad Steve Wozniak           1
# 909   Los mejores juegos de fútbol de hay son efootb...           0
#
#      reply_counts comments_emojis_count title_emojis_count desc_emojis_count
# 5244            0                     0                  0                 0
# 769             0                     0                  0                 0
# 1494            0                     0                  1                 0
# 619             0                     0                  0                 0
# 909             0                     0                  0                 0
#
# [5 rows x 23 columns]

# %% [markdown]
# #### *Language detection*

# %%
language_detector = transformers.pipeline("text-classification",
                                          model="papluca/xlm-roberta-base-language-detection",
                                          use_auth_token= True)

# %%
# %%timeit
print(language_detector("هذا أطول نص قد تقرأه على الإطلاق إنه طويل للغاية", max_length=128))
# Out:
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# [{'label': 'ar', 'score': 0.9917784333229065}]
# [{'label': 'ar', 'score': 0.9917784333229065}]
# [{'label': 'ar', 'score': 0.9917784333229065}]
# [{'label': 'ar', 'score': 0.9917784333229065}]
# [{'label': 'ar', 'score': 0.9917784333229065}]
# [{'label': 'ar', 'score': 0.9917784333229065}]
# [{'label': 'ar', 'score': 0.9917784333229065}]
# [{'label': 'ar', 'score': 0.9917784333229065}]
# 2.19 s ± 179 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# Looks like we will take a lot to <ins>just classify the language</ins> of each text at least: $30\times100$ second whitch equalls <span style="color: red">**50 minutes.**</span><br>
# So we can't do translation for now becuase it at least may take **5 hours** to run so we will just use this language detetion and<br>
# optimize it by just sellecting one text column to detect which will be **Description column** and use the detected languages to<br>
# pridect video and comments language.<br><br>
# But we will detect the language using the **country of this video**

# %%
df["country"].unique()
# Out:
# array(['US', 'DE', 'CA', 'BR', 'SG', 'IN', 'SA', 'AU', 'ID', 'EG', 'PH',
#        'PK', 'AE'], dtype=object)

# %%
country_languages = {
    'DE': 'German',
    'US': 'English', 'PL': 'Polish',
    'SA': 'Arabic', 'NP': 'Nepali',
    'CA': 'English', 'ES': 'Spanish',
    'TR': 'Turkish', 'IN': 'Hindi',
    'EG': 'Arabic', 'GB': 'English',
    'MX': 'Spanish', 'BR': 'Portuguese',
    'PK': 'Urdu', 'FR': 'French',
    'VN': 'Vietnamese', 'ID': 'Indonesian',
    'AU': 'English', 'HU': 'Hungarian',
    'NL': 'Dutch', 'BG': 'Bulgarian',
    'JP': 'Japanese', 'SG': 'English', 
    'TH': 'Thai', 'PH': 'Tagalog',
    'MT': 'Maltese', 'PE': 'Spanish',
    'SE': 'Swedish', 'IT': 'Italian',
    'KR': 'Korean', 'TW': 'Chinese',
    'FI': 'Finnish', 'DZ': 'Arabic',
    'BD': 'Bengali', 'AR': 'Spanish'}

df["language"] = df["country"].replace(country_languages)

# %% [markdown]
# This way may not be so accurate in detecting languages becuase there are some **indian videos** specifically with english and<br>
# because some commetns come in deffrint languages but at least this way is more accurate than `roberta-language-detection`<br>
# model because this model sometimes come with wierd.

# %% [markdown]
# #### *Sentiment analysis*

# %%
sentiment_classifier = transformers.pipeline(model= "finiteautomata/bertweet-base-sentiment-analysis")
print(sentiment_classifier("Hello here in my analysis, Have a nice day !!"))
# Out:
# Downloading:   0%|          | 0.00/2.68k [00:00<?, ?B/s]
# [{'label': 'POS', 'score': 0.9883897304534912}]

# %%
def my_sentiment_classifier(text: str) -> np.int8:
    """This code takes a text and return you if it's positive
        or negative as 1 for positive, 0 for natural -1 for negative
        and -10 for unclassified.
    
    @params: a string text
    @return: 1, 0 or -1 in np.int8 dtype"""
    
    global sentiment_type_encoder
    
    sentiment_type_encoder = {"POS": 2,
                              "NEG": -1,
                              "NEU": 1,
                              "unclassified": 0}
    
    try:
        sentiment_type: str = sentiment_classifier(text)[0]["label"]

    except Exception as e:
        sentiment_type: str = "unclassified"

    return  np.int8(sentiment_type_encoder[sentiment_type])

# %%
df["comments_sentiments"] = df["comments"].apply(
    lambda x: my_sentiment_classifier(x))

df[["comments_sentiments", "comments"]][:5]
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (130 > 128). Running this sequence through the model will result in indexing errors
#       comments_sentiments                                           comments
# 619                     1            virgin Steve Jobs vs Chad Steve Wozniak
# 2111                    1                                             Me too
# 4142                    1                   I need a friend like sapro 😭😭😭😭😭
# 2156                   -1  Very unclear directions, I suppose you just ma...
# 385                    -1  I played it on my Xbox one but unfortunately m...

# %% [markdown]
# Now we will drop the comments column becuase we already have done the **sentiment analysis** process.<br>
# so now we'll group the data by the `video_id` column.

# %% [markdown]
# ##### **Important note:**
# We will create other **data frame** to store the comments <ins>temporary</ins> so we can create our comments<br>
# **WordCloud**.

# %%
comments_cols = ['video_id', 'reply_counts', 'comments_sentiments',
                 'like_counts', "comments_emojis_count"]

temp_comments_df = df[["comments", "language", "title"]].copy()


# Here we will groupby the sentiments to be just one feature
comments_sentiments = df[comments_cols].copy()
comments_sentiments = comments_sentiments.groupby("video_id").sum().reset_index()
comments_sentiments.rename(columns= {"comments_sentiments": "sentiments"}, inplace= True)

    
df.drop(comments_cols[1:] + ["comments"],
        axis= 1, inplace= True)

df.drop_duplicates(inplace= True)
df.reset_index(inplace= True)
df.drop(["index"], axis= 1, inplace= True)


del TEXT_COLUMNS[1] # "comments" element
# Out:
# C:\Users\FreeComp\AppData\Local\Temp\ipykernel_15180\2773865321.py:9: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   comments_sentiments = comments_sentiments.groupby("video_id").sum().reset_index()

# %%
display(Markdown(f"The length of `comments_sentiments` dataframe is ${len(comments_sentiments)}$ " + \
                 f"and also the length of the main dataframe is ${len(df)}$ so every thing is <br>working fine "))
# Out:
# The length of `comments_sentiments` dataframe is $48$ and also the length of the main dataframe is $48$ so every thing is <br>working fine

# %%
df = pd.merge(df, comments_sentiments, on='video_id', how= 'outer')

df.head()
# Out:
#       video_id      channelTitle  \
# 0  p5IaCTJdVuM  Gaming Historian
# 1  zoAEVZOy5bI     K-City Gaming
# 2  GpaGzygr0mc      Sapro Gaming
# 3  AE6QNsfLyP8     Legacy Gaming
# 4  OQHO2i-ioxM     Skvala Gaming
#
#                                                title  \
# 0  Before Apple: Steve Jobs at Atari | Gaming His...
# 1                           Hide n Seek in AMONG US!
# 2                 What if a Gamer can Control Time 2
# 3  Unlock Your House Chest FAST In Hogwarts Legac...
# 4  Unleashing The Force- Star Wars Jedi: Fallen O...
#
#                                          description  \
# 0  New viewer? Subscribe! ► http://goo.gl/WCIhMQ\...
# 1  Today K-City Family is playing Hide and Seek i...
# 2  What if a Gamer can Control Time 2\nShop cheap...
# 3  By now you've most likely stumbled across your...
# 4  Welcome to our gameplay test of Star Wars Jedi...
#
#                                                 tags  \
# 0  ['Steve Jobs', 'Steve Wozniak', 'Nolan Bushnel...
# 1  ['k-city gaming', 'k-city', 'gaming', 'funny',...
# 2  ['What if a Gamer can Control Time 2', 'when a...
# 3  ['Legacy Gaming', 'hogwarts legacy', 'hogwarts...
# 4  ['star wars', 'star wars jedi fallen order', '...
#
#                  publishedAt viewCount likeCount commentCount definition  ...  \
# 0  2017-09-08 16:50:15+00:00    436441     14835         1604         hd  ...
# 1  2023-02-25 16:00:37+00:00    486988      4681          268         hd  ...
# 2  2021-03-20 13:00:14+00:00    198462      9933         1583         hd  ...
# 3  2023-02-07 16:00:10+00:00     83541      2154          225         hd  ...
# 4  2023-04-06 10:25:47+00:00      3064       134           52         hd  ...
#
#   total_views                 date video_count  \
# 0   124399915  2006-07-17 00:00:00         142
# 1   919201806  2016-04-06 00:00:00         458
# 2    59534959  2018-04-18 00:00:00         130
# 3    68443206  2017-07-19 00:00:00        1528
# 4    39882836  2018-02-03 00:00:00         559
#
#                                                about country  \
# 0  The Gaming Historian is a documentary series a...      US
# 1  K-City Gaming  (Formerly KidCity Gaming) is a ...      US
# 2  Hi, I'm Sapro! I make Stickman Animations rela...      US
# 3  Leave a Legacy!\n\nJoin Codiak and Livid and b...      US
# 4  Hello, welcome to my channel.\nI create tech &...      DE
#
#   title_emojis_count desc_emojis_count  language  sentiments  \
# 0                  0                 0   English           1
# 1                  0                 0   English           1
# 2                  0                 0   English           1
# 3                  0                 0   English          -1
# 4                  0                 0    German          -1
#
#   comments_emojis_count
# 0                     0
# 1                     0
# 2                     5
# 3                     0
# 4                     0
#
# [5 rows x 22 columns]

# %%
df['sentiments'] = df['sentiments_x']
df['comments_emojis_count'] = df['comments_emojis_count_x']

df.drop(["sentiments_x", "sentiments_y",
         "comments_emojis_count_x", "comments_emojis_count_y"],
        inplace= True, axis= 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\.conda\envs\youtube_gaming\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\.conda\envs\youtube_gaming\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\.conda\envs\youtube_gaming\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'sentiments_x'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[282], line 1
# ----> 1 df['sentiments'] = df['sentiments_x']
#       2 df['comments_emojis_count'] = df['comments_emojis_count_x']
#       4 df.drop(["sentiments_x", "sentiments_y",
#       5          "comments_emojis_count_x", "comments_emojis_count_y"],
#       6         inplace= True, axis= 1)
#
# File ~\.conda\envs\youtube_gaming\lib\site-packages\pandas\core\frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~\.conda\envs\youtube_gaming\lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'sentiments_x'

# %% [markdown]
# #### *Video stats range*

# %% [markdown]
# We will classify each column of **[Comments, Likes, Views]** into 6 groups manually like:
# <ul>
#     <li>  $1\sim3,000$ Views
#     <li>  $3,000\sim10,000$ Views
#     <li>  $10,000\sim50,000$ Views
#     <li>  $50,000\sim100,000$ Views
#     <li>  $100,000\sim300,000$ Views
#     <li>  $300,000\sim\infty$

# %% [markdown]
# We will see the max calues of each column so we can optimize it with the best dtype for it.

# %%
print(f" The max value of view count column is: {df['viewCount'].astype(int).max()}\n",
      f"The max value of like count column ias: {df['likeCount'].astype(int).max()}\n",
      f"The max value of comment count column is: {df['commentCount'].astype(int).max()}\n",
      f"The max value of subscribers column is: {df['subscribers'].astype(int).max()}\n")
# Out:
#  The max value of view count column is: 67652856
#  The max value of like count column ias: 1164572
#  The max value of comment count column is: 37636
#  The max value of subscribers column is: 32000000

# %%
df = df.astype({"commentCount": np.uint16, "viewCount": np.uint32,
                "likeCount": np.uint16, "subscribers": np.uint32})

df.describe()
# Out:
#           viewCount     likeCount  commentCount  duration_in_minutes  \
# count  4.800000e+01     48.000000     48.000000            48.000000
# mean   1.811569e+06  10669.291667   1322.854167            24.650064
# std    9.730748e+06  12130.494607   5385.437922            48.970753
# min    2.186000e+03      1.000000     52.000000             0.750000
# 25%    3.459600e+04   1394.750000    114.750000             9.798828
# 50%    1.683990e+05   5493.000000    336.000000            14.257812
# 75%    3.941002e+05  15736.750000    835.250000            21.113281
# max    6.765286e+07  50460.000000  37636.000000           339.500000
#
#         subscribers   total_views  video_count  title_emojis_count  \
# count  4.800000e+01  4.800000e+01    48.000000           48.000000
# mean   1.970588e+06  5.146656e+08   880.479167            0.145833
# std    4.855950e+06  1.071874e+09   941.134896            0.545371
# min    2.380000e+04  1.554424e+06    43.000000            0.000000
# 25%    1.482500e+05  3.740742e+07   170.500000            0.000000
# 50%    5.955000e+05  1.140617e+08   472.000000            0.000000
# 75%    1.860000e+06  5.104331e+08  1275.750000            0.000000
# max    3.200000e+07  5.648937e+09  3754.000000            3.000000
#
#        desc_emojis_count  sentiments  comments_emojis_count
# count          48.000000   48.000000               48.00000
# mean            0.020833    0.958333                1.00000
# std             0.144338    0.898186                4.66768
# min             0.000000   -1.000000                0.00000
# 25%             0.000000    1.000000                0.00000
# 50%             0.000000    1.000000                0.00000
# 75%             0.000000    1.000000                0.00000
# max             1.000000    3.000000               32.00000

# %%
df["cat_view_count"] = pd.cut(df['viewCount'],
                         bins=[1, 3_000, 10_000, 50_000, 100_000, 300_000, 999_999_999_999],
                         labels=["from 1 to 3,000", "from 3,000 to 10,000",
                                 "from 10,000 to 50,000", "from 50,000 to 100,000",
                                 "from 100,000 to 300,000", "more than 300,000"])

df["cat_comment_count"] = pd.cut(df['commentCount'],
                         bins=[50, 100, 150, 200, 400, 600, 999_999_999_999],
                         labels=["from 50 to 100", "from 100 to 150",
                                 "from 150 to 200", "from 200 to 400",
                                 "from 400 to 600", "more than 600"])

df["cat_like_count"] = pd.cut(df['likeCount'],
                         bins=[0, 1_000, 5_000, 10_000, 50_000, 150_000, 999_999_999_999],
                         labels=["from 1 to 1,000", "from 1,000 to 5,000",
                                 "from 5,000 to 10,000", "from 10,000 to 50,000",
                                 "from 50,000 to 150,000", "more than 150,000"])

# %%
df[["cat_view_count", "cat_comment_count", "cat_like_count",
    "viewCount", "commentCount", "likeCount"]].sample(5)
# Out:
#              cat_view_count cat_comment_count         cat_like_count  \
# 9   from 100,000 to 300,000     more than 600   from 5,000 to 10,000
# 19        more than 300,000   from 200 to 400  from 10,000 to 50,000
# 39    from 10,000 to 50,000   from 200 to 400    from 1,000 to 5,000
# 10        more than 300,000     more than 600  from 10,000 to 50,000
# 44          from 1 to 3,000    from 50 to 100        from 1 to 1,000
#
#     viewCount  commentCount  likeCount
# 9      168575           911       8671
# 19    1133417           346      14870
# 39      26766           330       1349
# 10     989728          1659      42146
# 44       2186            85          1

# %% [markdown]
# #### *Text columns length*

# %%
for col in TEXT_COLUMNS:
    df[f"{col}_length"] = df[col].str.len()
    df[f"{col}_length"] = df[f"{col}_length"].astype(np.uint16)

# %% [markdown]
# ## <center><strong>Text visualiztion with<span style = "color: red"> WordCloud</span></strong></center>

# %%
coloring = np.array(Image.open("../imgs/youtube_gaming_logo.png"))
stopwords = set(STOPWORDS)

comments = ''.join(
    temp_comments_df["comments"][temp_comments_df["language"] == "English"].values.flatten())

# %%
comments_wc = WordCloud(background_color= "white", max_words= 300, mask= coloring,
               stopwords= stopwords, max_font_size= 80, random_state= 42,
               font_path= '../Data analysis/assets/fonts/FranklinGothic.ttf',
               collocations=False)

image_colors = ImageColorGenerator(np.array(coloring))
comments_wc.generate(comments)
comments_wc = comments_wc.recolor(color_func= image_colors)

comments_svg = comments_wc.to_svg(embed_font=True)

# Save the SVG code to a file
with open("../plots/comments_word_cloud.svg", "w", encoding="utf-8") as f:
    f.write(comments_svg)
    
fig, ax = plt.subplots(1)

ax.imshow(comments_wc, interpolation="bilinear")
ax.set_axis_off()

plt.title("Comments word cloud")
fig.set_size_inches(10, 8)
plt.savefig("../plots/comments_word_cloud.png")
plt.show()

# %% [markdown]
# Now we will make a word cloud for **video titles data**

# %%
popular_emojis = ["😊", "😍", "😘", "😜", "😝", "😂", "😭", "😡", "😠", "😩", "😫", "😞", "😟", "😢", "😥", "😰", "😱",
                       "😳", "😷", "👍", "👎", "👌", "👏", "🙌", "👋", "💪", "🙏", "❤️", "💔", "💕", "💖", "💘", "💙", "💚",
                       "💛", "💜", "💯", "🔥", "🌟", "✨", "⭐", "🌈", "🌺", "🍕", "🍔", "🍟", "🍦", "🍭", "🍩", "🍪", "🍺",
                       "🍻", "🍷", "🍸", "🎂", "🎁", "🎉", "🎊", "🎈", "🎵", "🎶", "🎼", "🎧", "🎤", "🎸", "🎹", "🎺", "🎷",
                       "🎻", "🎬", "🎥", "🎦", "📷", "📹", "📺", "📻", "💻", "📱", "💡", "🔑", "🔨", "🔥", "💰", "💳", "💼",
                       "📅", "📆", "📈", "📉", "📊", "📋", "📎", "📏", "📐", "🔒", "🔓", "🔍", "🔎", "🚀", "🚑", "🚒", "🚓",
                       "🚕", "🚗", "🚙", "🚚", "🚢", "🚤", "🚲", "🚶", "🚶‍♀️", "🏃", "🏃‍♀️", "⚽", "🏀", "🏈", "🎾", "🏐", "🏉",
                       "🎱", "🏓", "🏸", "🥊", "🥋", "🎮", "🕹️", "🎲", "🃏"]


for emoji in popular_emojis:
    stopwords.add(emoji)
    
titels = ''.join(
    temp_comments_df["title"][temp_comments_df["language"] == "English"].values.flatten())

# %%
coloring = np.array(Image.open("../imgs/joystick.png"))

titels_wc = WordCloud(background_color= "white", max_words= 2000, mask= coloring,
               stopwords= stopwords, max_font_size= 80, random_state= 42,
               font_path= '../Data analysis/assets/fonts/FranklinGothic.ttf')

titels_wc.generate(titels)
image_colors = ImageColorGenerator(np.array(coloring))
titels_wc = titels_wc.recolor(color_func= image_colors)


fig, ax = plt.subplots(1)

ax.imshow(titels_wc, interpolation= "bilinear")
ax.set_axis_off()

titels_svg = titels_wc.to_svg(embed_font=True)

with open("../plots/videos_titels_word_cloud.svg", "w", encoding="utf-8") as f:
    f.write(titels_svg)

plt.title("Video titles word cloud")
fig.set_size_inches(10, 8)
plt.savefig("../plots/videos_titels_word_cloud.png")
plt.show()

# %%
del temp_comments_df

# %% [markdown]
# ## <center><strong><span style = "color: red">NLP</span> preprocessing

# %% [markdown]
# #### *Removing stop words*

# %%
from nltk.corpus import stopwords
# nltk.download()

nltk.download('punkt', force=True)
nltk.download('wordnet', force= True)
nltk.download('stopwords', force=True)
nltk.download('stopwords-hi', force=True)
nltk.download('stopwords-ar', force=True)
nltk.download('averaged_perceptron_tagger', force=True)


en_stopwords = set(stopwords.words('english')) 
ar_stopwords = set(stopwords.words('arabic')) 
# hi_stopwords = set(stopwords.words('hindi')) 

all_stopwords = en_stopwords.union(ar_stopwords)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\FreeComp\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\FreeComp\AppData\Roaming\nltk_data...
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\FreeComp\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# [nltk_data] Error loading stopwords-hi: Package 'stopwords-hi' not
# [nltk_data]     found in index
# [nltk_data] Error loading stopwords-ar: Package 'stopwords-ar' not
# [nltk_data]     found in index
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\FreeComp\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger.zip.

# %%
def stopwords_dropper(words: list, stopwords: set) -> list:
    
    # Removing stop words from unalphabetical chars
    filtered_words = [re.sub(r"[\W_]", "", word) for word in words
                      if not word in stopwords]
    
    filtered_words = list(filter(lambda item: item != "", filtered_words))
    return  filtered_words


for col in TEXT_COLUMNS:
    df[f"{col}_tokens"] = df[col].apply(lambda text: nltk.word_tokenize(text.lower()))
    df[f"{col}_tokens"] = df[f"{col}_tokens"].apply(lambda text: stopwords_dropper(text,
                                                                     all_stopwords))

df["title_tokens"]
# Out:
# 0        [apple, steve, jobs, atari, gaming, historian]
# 1                            [hide, n, seek, among, us]
# 2                             [gamer, control, time, 2]
# 3     [unlock, house, chest, fast, hogwarts, legacy,...
# 4     [unleashing, force, star, wars, jedi, fallen, ...
# 5     [built, high, speed, precision, track, pros, l...
# 6     [apenas, um, sai, vivo, dessa, prisão, roblox,...
# 7     [ကလလမကက, အသညကပ, gta, v, baby, gang, roleplay, ...
# 8     [ಬಗಳರ, goa, train, journey, vasco, express, ka...
# 9     [hw, news, amd, make, 7600x3d, 400, folding, k...
# 10            [warden, ki, portal, khol, de, minecraft]
# 11    [beat, mass, effect, without, mako, me1, mako,...
# 12                    [تسرق, بسكويت, الجدة, أكبر, غلطة]
# 13                                                [mad]
# 14    [efootball, 2023, vs, dls, 22, vs, fifa, 22, v...
# 15    [36, killsmy, best, gameplay, solo, vs, squad,...
# 16    [back, dead, 3dfx, s, unreleased, voodoo5, 600...
# 17                     [chaos, animal, crossing, chaos]
# 18                    [slendrina, forest, mobile, game]
# 19    [super, beginning, 30400, coins, 2085, diamond...
# 20            [reacting, insane, snowboarding, crashes]
# 21    [made, virat, kohli, painting, build, battle, ...
# 22    [shinchan, franklin, tried, impossible, longes...
# 23                 [10000, zombies, vs, mutant, wither]
# 24                             [old, dhanu, dino, back]
# 25                    [jurassic, world, mod, among, us]
# 26                         [xqc, s, ai, goes, unhinged]
# 27                                          [اكثر, اقل]
# 28    [basic, image, recognition, pyautogui, video, ...
# 29                          [garbage, gaming, lan, box]
# 30        [random, skin, challenge, garena, free, fire]
# 31    [rekap, patch, note, 1768, original, server, m...
# 32                              [فيلم, اليوتيوب, حياتى]
# 33    [duel, wall, riding, mine, train, coasters, av...
# 34          [stuck, cave, else, long, dark, permadeath]
# 35    [v, badge, trick, free, fire, 2023, shorts, ga...
# 36    [asmongold, loses, mind, playing, bleak, faith...
# 37                         [payal, ka, deewana, omegle]
# 38           [ausbruch, aus, spielzeug, fabrik, roblox]
# 39    [rust, raid, dat, base, ep, 1, rust, base, des...
# 40            [secret, nuck, bunker, house, flipper, 6]
# 41               [chester, worth, unlocking, upgrading]
# 42    [unang, karera, ni, von, sa, race, track, semp...
# 43    [minecraft, noob, vs, hacker, tiny, alphabet, ...
# 44    [free, emote, emerald, card, event, free, fire...
# 45    [tier, list, every, mode, best, brawlers, braw...
# 46     [got, glacier, phir, sy, glacier, zalmi, gaming]
# 47      [فيلم, روبلوكس, ميجو, 9, اتحبس, مسلسلات, رمضان]
# Name: title_tokens, dtype: object

# %% [markdown]
# #### *Part-of-speech (POS) Tagging*

# %%
for col in TEXT_COLUMNS:
    df[f"{col}_pos_tags"] = df[f"{col}_tokens"].apply(lambda words: nltk.pos_tag(words))

df["about_pos_tags"]
# Out:
# 0     [(gaming, VBG), (historian, JJ), (documentary,...
# 1     [(kcity, NN), (gaming, VBG), (formerly, RB), (...
# 2     [(hi, NN), (m, NN), (sapro, JJ), (make, VBP), ...
# 3     [(leave, VB), (legacy, NN), (join, NN), (codia...
# 4     [(hello, JJ), (welcome, JJ), (channel, NN), (c...
# 5               [(video, NN), (games, NNS), (life, NN)]
# 6     [(beto, NN), (robin, NN), (hood, NN), (e, NN),...
# 7     [(like, IN), (playing, VBG), (games, NNS), (mo...
# 8     [(free, JJ), (fire, NN), (kannada, NN), (conte...
# 9     [(pc, NN), (hardware, NN), (reviews, VBZ), (ga...
# 10    [(gaming, VBG), (youtuber, NNP), (chapatigamer...
# 11    [(subscribe, NN), (videos, NNS), (rpgs, VBP), ...
# 12    [(قناة, JJ), (عائلة, NNP), (مشيع, NNP), (الرسم...
# 13    [(welcome, JJ), (blue, NN), (gaming, NN), (cha...
# 14    [(focusing, VBG), (quality, NN), (quantity, NN...
# 15    [(hey, NN), (subscribe, NN), (1000, CD), (subs...
# 16    [(pc, NN), (hardware, NN), (reviews, VBZ), (ga...
# 17    [(hello, NN), (s, JJ), (nicole, JJ), (friends,...
# 18    [(bengali, NN), (gaming, VBG), (channel, NN), ...
# 19    [(focusing, VBG), (quality, NN), (quantity, NN...
# 20    [(optic, JJ), (dominant, JJ), (team, NN), (his...
# 21                      [(quality, NN), (quantity, NN)]
# 22    [(two, CD), (brothers, NNS), (trying, VBG), (e...
# 23    [(mrbeast, NN), (gaming, VBG), (subscribe, NN)...
# 24    [(hello, NN), (freefire, NN), (lovers, NNS), (...
# 25    [(welcome, JJ), (gametoons, NNS), (gaming, VBG...
# 26    [(please, VB), (send, JJ), (message, NN), (con...
# 27    [(اسوأ, JJ), (قناة, NNP), (قيمنق, NNP), (التار...
# 28    [(enjoy, NN), (helping, VBG), (beginners, NNS)...
# 29    [(relaxed, JJ), (goofy, NN), (tech, NN), (vide...
# 30    [(hello, NN), (name, NN), (sumo, JJ), (channel...
# 31    [(welcome, JJ), (channel, NN), (find, VBP), (m...
# 32    [(احنا, JJ), (عيلة, NNP), (بسيطة, NNP), (وعندن...
# 33    [(channel5, NN), (gaming, VBG), (planet, NN), ...
# 34    [(cinematic, JJ), (gameplay, NN), (neebs, RB),...
# 35    [(dhanbad, NN), (youtube, NN), (handle, JJ), (...
# 36    [(official, JJ), (asmongold, JJ), (vod, NN), (...
# 37    [(first, RB), (channel, NN), (antaryami, NN), ...
# 38    [(der, NN), (neue, DT), (kanal, JJ), (von, NN)...
# 39                                                   []
# 40                           [(play, NN), (games, NNS)]
# 41    [(m, NN), (kairostime, NN), (s, JJ), (time, NN...
# 42    [(hey, NN), (welcome, VBP), (sa, NN), (best, R...
# 43    [(pro, JJ), (players, NNS), (subscribe, VBP), ...
# 44    [(dhanbad, NN), (youtube, NN), (handle, JJ), (...
# 45    [(m, NN), (kairostime, NN), (s, JJ), (time, NN...
# 46    [(zalmi, NN), (gaming, VBG), (youtube, JJ), (c...
# 47    [(هاي, JJ), (اصدقائى, NNP), (بحبكو, NNP), (جدا...
# Name: about_pos_tags, dtype: object

# %% [markdown]
# #### *Lemmatization and dropping duplicated words*

# %%
def get_wordnet_pos(treebank_tag: str) -> str:
    
    if treebank_tag.startswith('J'):
        return wordnet.ADJ
    
    elif treebank_tag.startswith('V'):
        return wordnet.VERB
    
    elif treebank_tag.startswith('N'):
        return wordnet.NOUN
    
    elif treebank_tag.startswith('R'):
        return wordnet.ADV
    
    else:
        return wordnet.NOUN

# %%
lemmatizer = WordNetLemmatizer()
lemmatized_words = []
lemmatized_words_group = []

for col in TEXT_COLUMNS:
    for index, row in df.iterrows():
        for token, pos_tag in zip(row[f"{col}_tokens"], row[f"{col}_pos_tags"]):

            wordnet_pos = get_wordnet_pos(pos_tag[1])
            lemmatized_words_group.append(lemmatizer.lemmatize(token, pos= wordnet_pos))
            lemmatized_words_group = list(set(lemmatized_words_group)) # Dropping duplicates


        lemmatized_words.append(lemmatized_words_group)
        lemmatized_words_group = [] # clearing this list
    
    df[f"{col}_tokens"] = lemmatized_words
    lemmatized_words = []

# %%
df["channelTitle_tokens"][:5]
# Out:
# 0    [game, historian]
# 1      [kcity, gaming]
# 2      [sapro, gaming]
# 3       [game, legacy]
# 4     [gaming, skvala]
# Name: channelTitle_tokens, dtype: object

# %% [markdown]
# #### *One hot encoding*

# %%
df["language"] = df["language"].astype("category")# .cat.codes
df["definition"] = df["definition"].astype("category")# .cat.codes
df["country"] = df["country"].astype("category")
df["sentiments"] = df["sentiments"].astype(np.int8)

df["cat_view_count"] = df["cat_view_count"].replace({"from 1 to 3,000": 1, "from 3,000 to 10,000": 2,
                                                     "from 10,000 to 50,000": 3, "from 50,000 to 100,000": 4,
                                                     "from 100,000 to 300,000": 5, "more than 300,000": 6})

df["cat_like_count"] = df["cat_like_count"].replace({"from 1 to 1,000": 1, "from 1,000 to 5,000": 2,
                                                     "from 5,000 to 10,000": 3, "from 10,000 to 50,000": 4,
                                                     "from 50,000 to 150,000": 5, "more than 150,000": 6})

df["cat_comment_count"] = df["cat_comment_count"].replace({"from 50 to 100": 1, "from 100 to 150": 2,
                                                           "from 150 to 200": 3, "from 200 to 400": 4,
                                                           "from 400 to 600": 5, "more than 600": 6})

# %%
df[["language", "definition", "cat_view_count",
    "cat_like_count", "cat_comment_count", "sentiments"]].sample(5)
# Out:
#    language definition cat_view_count cat_like_count cat_comment_count  \
# 33  English         hd              3              1                 1
# 4    German         hd              2              1                 1
# 37    Hindi         hd              5              4                 4
# 28  English         hd              3              1                 1
# 43     Urdu         hd              5              3                 2
#
#     sentiments
# 33           1
# 4           -1
# 37           1
# 28           2
# 43           1

# %% [markdown]
# ## <center><strong><span style = "color: red">Text</span> classification

# %% [markdown]
# #### *Preparing training & testing data*

# %%
# Changing dtypes of some colums:hh
df = df.astype({"total_views": np.uint64, "video_count": np.uint16,
                "duration_in_minutes": np.float32, "date": "datetime64[ns]",
                "publishedAt": "datetime64[ns]"})


# Those are just temporary text columns not the main one.
text_cols = ["tags", "about_tokens", "title_tokens",
             "channelTitle_tokens", "description_tokens"]

cat_cols = ["country", "language", "definition"]

numeric_cols = [*df.select_dtypes(NUMERICS).columns]

target_cols = ["cat_view_count", "cat_like_count", "cat_comment_count"]

date_cols = ["date", "publishedAt"]



X = df[numeric_cols + cat_cols + date_cols + text_cols]
y = df[target_cols]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 1/ 5, random_state= 99)

print(f"The shape of the X train data is: {X_train.shape}")
print(f"The shape of the y test data is: {y_test.shape}")

del X, y
# Out:
# The shape of the X train data is: (38, 24)
# The shape of the y test data is: (10, 3)

# %%
X_test
# Out:
#     viewCount  likeCount  commentCount  duration_in_minutes  subscribers  \
# 28      26246        575            56            60.031250        23800
# 26     222820       5509           300            92.062500       137000
# 11      15200       1169           188             8.718750       117000
# 37     168223      19822           398             8.867188      4030000
# 36      24076        343           126           339.500000        67600
# 13      17532        962            58            19.828125       123000
# 16     426582      21596          2616            30.609375      1860000
# 21     177728      17932            57             0.799805       833000
# 19    1133417      14870           346            33.718750       346000
# 34     212753      10972           927            44.875000      2330000
#
#     total_views  video_count  title_emojis_count  desc_emojis_count  \
# 28      1554424           43                   0                  0
# 26     52943262         1225                   0                  0
# 11     42185774          433                   0                  0
# 37    721871325         1569                   0                  0
# 36     11317959           78                   0                  0
# 13      6180511          311                   0                  0
# 16    510433077         2734                   0                  0
# 21    124185542          373                   0                  0
# 19    103937897           84                   0                  0
# 34   1140711623         2418                   0                  0
#
#     comments_emojis_count  ...  country  language  definition       date  \
# 28                      0  ...       US   English          hd 2019-10-06
# 26                      0  ...       US   English          hd 2021-10-14
# 11                      0  ...       US   English          hd 2019-05-29
# 37                      2  ...       IN     Hindi          hd 2018-03-05
# 36                      0  ...       US   English          hd 2022-09-08
# 13                      0  ...       CA   English          hd 2019-12-16
# 16                      1  ...       US   English          hd 2009-05-12
# 21                      0  ...       IN     Hindi          hd 2018-03-15
# 19                      2  ...       US   English          hd 2018-11-27
# 34                      0  ...       US   English          hd 2014-03-16
#
#            publishedAt                                               tags  \
# 28 2019-11-26 18:35:30  ['pyautogui', 'pyautogui game bot', 'mmo bot',...
# 26 2023-03-18 15:17:09  ['xQc', 'xqc', 'xqcow', 'overwatch', 'twitch',...
# 11 2023-04-09 22:15:01  ['big dan gaming', 'can you beat mass effect w...
# 37 2023-04-01 15:31:28  ['antaryami gaming', 'antaryami', 'omegle', 'a...
# 36 2023-03-15 03:08:07  ['vod', 'asmongold vod', 'full vod', 'asmongol...
# 13 2023-01-22 09:00:10  ['pubg mobile', 'pubgm', 'pubgmvip', 'PUBG MOB...
# 16 2023-04-07 23:27:41  ['gamersnexus', 'gamers nexus', 'computer hard...
# 21 2022-11-04 10:21:13                      ['minecraft', 'build battle']
# 19 2023-01-13 11:00:37  ['dls 23', 'dls', 'dream league soccer 2023', ...
# 34 2023-01-21 17:30:01  ['the long dark', 'the long dark gameplay', 's...
#
#                                          about_tokens  \
# 28  [help, thing, tutorial, fun, ben, enjoy, offer...
# 26  [send, message, dailydoseofxqc, manage, please...
# 11  [cyberpunk, 2077, walkthroughs, effect, scroll...
# 37  [workforantaryami, apka, upar, rb, search, cho...
# 36  [daily, longer, catdany, stream, vod, gmailcom...
# 13                   [blue, channel, welcome, gaming]
# 16  [please, review, update, hardware, analysis, s...
# 21                                [quality, quantity]
# 19  [highquality, quantity, focus, enquire, video,...
# 34  [great, join, challenge, friendship, xo, perfe...
#
#                                          title_tokens    channelTitle_tokens  \
# 28  [basic, pyautogui, video, 44, tutorial, recogn...  [code, learn, gaming]
# 26                         [s, xqc, unhinged, ai, go]          [xqc, gaming]
# 11  [beat, mass, playthrough, effect, mako, withou...     [big, dan, gaming]
# 37                       [ka, omegle, payal, deewana]    [antaryami, gaming]
# 36  [mind, bleak, lose, forsaken, faith, play, asm...    [asmongold, gaming]
# 13                                              [mad]         [blue, gaming]
# 16  [card, s, voodoo5, dead, 6000, unreleased, 3df...        [gamers, nexus]
# 21  [minecraft, short, battle, paint, virat, kohli...       [navrit, gaming]
# 19  [r2g, 23, begin, free, coin, super, dls, agent...       [game, hd, gang]
# 34        [permadeath, long, else, dark, stick, cave]          [game, neebs]
#
#                                    description_tokens
# 28  [stuff, allow, listpl1m2m8lqlzfjde1xv1py5euslt...
# 26  [internet, listplker9ceyac9zh3czr0qgudq72hgvow...
# 11  [ever, effect, donate, instagram, way, inacces...
# 37  [paytm, join, wwwyoutubecomchanneluczxu, donat...
# 36  [internet, watch, ban, highlight, really, gmai...
# 13  [rezapanahi299, pubgmvip, wwwinstagramcomblueg...
# 16  [compete, ever, patchup, 2043, steve, join, ty...
# 21  [minecraft, youtubezxglwvxdhe, video, watch, m...
# 19  [r2g, coin, super, instagram, ggofficialcom, a...
# 34  [bitly1nokqlu, twittercomneebsofficial, wolf, ...
#
# [10 rows x 24 columns]

# %% [markdown]
# #### *preprocessing*

# %% [markdown]
# https://towardsdatascience.com/how-to-combine-textual-and-numerical-features-for-machine-learning-in-python-dc1526ca94d9

# %%
X_train["stacked_text"] = X_train[text_cols].agg(', '.join, axis=1).astype(str)
X_train["stacked_text"] = X_train["stacked_text"].str.replace("[", "")
X_train["stacked_text"] = X_train["stacked_text"].str.replace("]", "")

X_train["stacked_text"] = X_train[text_cols].agg(', '.join, axis=1).astype(str)
X_train["stacked_text"] = X_train["stacked_text"].str.replace("[", "")
X_train["stacked_text"] = X_train["stacked_text"].str.replace("]", "")

# %%
scaler = StandardScaler()
encoder = OneHotEncoder(handle_unknown='ignore', sparse=False)
tfidf = TfidfVectorizer()

preprocessor = ColumnTransformer(
transformers=[
    ('cat', encoder, cat_cols),
    ('num', scaler, numeric_cols),
    ('txt', tfidf, ["stacked_text"])])


for col in X_train[text_cols].columns:
     X_train[col] = X_train[col].astype(str)




X_train.drop(text_cols, inplace= True, axis= 1)

print(X_train.shape)
print(X_train.describe())

X_train = X_train[cat_cols + numeric_cols + ["stacked_text"]]

X_train = preprocessor.fit_transform(X_train)
# Out:
# (38, 20)
#           viewCount     likeCount  commentCount  duration_in_minutes  \
# count  3.800000e+01     38.000000     38.000000            38.000000
# mean   2.224493e+06  11009.894737   1537.500000            14.320852
# std    1.092749e+07  12963.876680   6038.559018             7.550655
# min    2.186000e+03      1.000000     52.000000             0.750000
# 25%    4.437250e+04   2004.000000    122.750000            10.044922
# 50%    1.574765e+05   5079.000000    354.000000            13.800781
# 75%    4.170222e+05  14962.500000    871.750000            18.132812
# max    6.765286e+07  50460.000000  37636.000000            32.718750
#
#         subscribers   total_views  video_count  title_emojis_count  \
# count  3.800000e+01  3.800000e+01    38.000000           38.000000
# mean   2.229495e+06  5.786481e+08   868.289474            0.184211
# std    5.402167e+06  1.184080e+09   936.783251            0.608732
# min    3.670000e+04  1.605435e+06    68.000000            0.000000
# 25%    2.040000e+05  4.098507e+07   187.250000            0.000000
# 50%    6.400000e+05  1.322444e+08   486.500000            0.000000
# 75%    1.787500e+06  4.929590e+08  1097.000000            0.000000
# max    3.200000e+07  5.648937e+09  3754.000000            3.000000
#
#        desc_emojis_count  comments_emojis_count  title_length  \
# count          38.000000              38.000000     38.000000
# mean            0.026316               1.131579     52.157895
# std             0.162221               5.235900     22.853856
# min             0.000000               0.000000     13.000000
# 25%             0.000000               0.000000     34.500000
# 50%             0.000000               0.000000     46.500000
# 75%             0.000000               0.000000     63.250000
# max             1.000000              32.000000    100.000000
#
#        description_length  channelTitle_length  about_length
# count           38.000000            38.000000     38.000000
# mean           799.447368            13.921053    234.973684
# std            720.572996             3.199507    221.289524
# min             42.000000             9.000000      0.000000
# 25%            318.250000            12.000000     92.250000
# 50%            550.500000            13.000000    153.000000
# 75%           1054.750000            16.000000    279.250000
# max           2803.000000            24.000000    884.000000
# C:\Users\FreeComp\AppData\Local\Temp\ipykernel_15180\459247879.py:18: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   X_train["stacked_text"] = X_train["stacked_text"].str.replace("[", "")
# C:\Users\FreeComp\AppData\Local\Temp\ipykernel_15180\459247879.py:19: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   X_train["stacked_text"] = X_train["stacked_text"].str.replace("]", "")
# C:\Users\FreeComp\AppData\Roaming\Python\Python39\site-packages\sklearn\preprocessing\_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[324], line 28
#      24 print(X_train.describe())
#      26 X_train = X_train[cat_cols + numeric_cols + ["stacked_text"]]
# ---> 28 X_train = preprocessor.fit_transform(X_train)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\sklearn\utils\_set_output.py:140, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     138 @wraps(f)
#     139 def wrapped(self, X, *args, **kwargs):
# --> 140     data_to_wrap = f(self, X, *args, **kwargs)
#     141     if isinstance(data_to_wrap, tuple):
#     142         # only wrap the first output for cross decomposition
#     143         return (
#     144             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     145             *data_to_wrap[1:],
#     146         )
#
# File ~\AppData\Roaming\Python\Python39\site-packages\sklearn\compose\_column_transformer.py:751, in ColumnTransformer.fit_transform(self, X, y)
#     748 self._validate_output(Xs)
#     749 self._record_output_indices(Xs)
# --> 751 return self._hstack(list(Xs))
#
# File ~\AppData\Roaming\Python\Python39\site-packages\sklearn\compose\_column_transformer.py:868, in ColumnTransformer._hstack(self, Xs)
#     865     output.columns = names_out
#     866     return output
# --> 868 return np.hstack(Xs)
#
# File <__array_function__ internals>:180, in hstack(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\numpy\core\shape_base.py:345, in hstack(tup)
#     343     return _nx.concatenate(arrs, 0)
#     344 else:
# --> 345     return _nx.concatenate(arrs, 1)
#
# File <__array_function__ internals>:180, in concatenate(*args, **kwargs)
#
# ValueError: all the input array dimensions for the concatenation axis must match exactly, but along dimension 0, the array at index 0 has size 38 and the array at index 2 has size 1

# %%
len(stacked_text)
# Out:
# 38

# %%
X_test[1: 5]
# Out:
# array([[ 0.        ,  0.        ,  1.        ,  1.        ,  0.        ,
#          1.        ,  0.27214812, -0.1202706 ,  1.08969061,  0.35723637,
#          0.02494485,  1.39513872, -0.1111673 ,  0.        ,  0.        ,
#          0.        , -1.58711242, -0.12280971,  0.33333333, -0.45542223],
#        [ 1.        ,  0.        ,  0.        ,  1.        ,  0.        ,
#          1.        , -0.52990126, -0.47568802, -0.5071284 , -0.90614414,
#         -0.59779393, -0.31932692,  2.79475823,  0.        ,  0.        ,
#          0.        ,  0.81933963, -0.67476347, -0.5       , -0.69222487],
#        [ 0.        ,  1.        ,  0.        ,  0.        ,  1.        ,
#          1.        , -0.13189566,  0.68544423, -0.72646041, -1.19951766,
#          2.68229981,  0.75989419, -0.46849078,  0.        ,  0.        ,
#          0.        ,  0.47556076, -1.13702475,  2.        , -0.52308012],
#        [ 0.        ,  0.        ,  1.        ,  1.        ,  0.        ,
#          1.        , -0.44763677, -0.37704598,  2.4343803 ,  2.4308373 ,
#         -0.71629079, -1.08556791, -0.8029089 ,  0.        ,  0.        ,
#          0.        ,  0.76204315, -0.58507099, -0.08333333, -0.81062619]])

# %%
X[text_cols] =

# %%
X_train
# Out:
#     viewCount  likeCount  commentCount  duration_in_minutes  subscribers  \
# 33      17532        962            58            19.828125       123000
# 10     144703       5977           628            20.187500       694000
# 6        3316        658            69             9.101562       112000
# 22    1028755      35144          2900            89.312500       187000
# 3     1133417      14870           346            33.718750       346000
# 42     175756       1831           231           413.500000       431000
# 24      43701       1954            88            12.882812       432000
# 32     637254      20420          1362            33.656250      1300000
# 44      10516        430            82            10.046875        24900
# 17       7859        482            57            79.250000       207000
# 31      48985       2393           366            19.000000       436000
# 41      26643       1203           172             5.199219       221000
# 14      19995        694           116            16.031250        36700
# 43      15652       1002            75            14.015625       123000
# 27     610043       9916           907             7.214844       236000
# 15     155228       5210           228            10.679688     13400000
# 7      686022      19206           404            19.250000      1080000
# 25     141495       6590           589            31.156250       741000
# 20      52146       1428           106             0.233276      1110000
# 30     352284       9500          1471            14.132812      3810000
# 8       31452       1262           532            13.414062       100000
# 12      76473       5720           134            11.914062      3130000
# 0       22361       3720            61             8.148438       288000
# 2        6599        267            79             2.900391       131000
# 38    1509153      26013           553            11.617188      2510000
# 29     373024      18037          1529            15.851562       244000
# 39     690049      14243          1194            19.500000       177000
# 46      46387        923            63            31.734375       122000
# 23      21431        907           116            13.382812       582000
# 47      38424       1536           250            16.671875        55300
# 5       42797        908            78             5.199219        58300
# 4      363904      11301          1019            15.179688       960000
# 18     428272      10415           817            15.179688      2080000
# 45     209423       3741            62             7.566406        36200
# 9      164385      12328          1774             9.882812       661000
# 40     179424       5632           544             9.046875     13400000
# 35      30649       1335           189            40.312500       252000
# 1       23226        951           168            35.156250       252000
#
#     total_views  video_count  title_emojis_count  desc_emojis_count  \
# 33      6180511          311                   0                  0
# 10     79491185          415                   1                  1
# 6       1605435          296                   0                  0
# 22     19574396           57                   0                  0
# 3     103937897           84                   0                  0
# 42     92148939          725                   0                  0
# 24    154452839         1496                   0                  0
# 32    201007558          346                   0                  0
# 44      3238246          173                   0                  0
# 17     20507678          365                   0                  0
# 31     72564072          493                   0                  0
# 41     44627833         2062                   0                  0
# 14      7848593          151                   0                  0
# 43      6180511          311                   0                  0
# 27    176038222         1793                   0                  0
# 15   4190823674         4196                   0                  0
# 7     191642862          464                   0                  0
# 25    178333901          309                   0                  0
# 20    284990998          575                   0                  0
# 30    905510842         2892                   0                  0
# 8      38364359          566                   0                  0
# 12    526793816          777                   0                  0
# 0      19974585          260                   0                  0
# 2      34179203         1389                   0                  0
# 38    757385776          260                   0                  0
# 29     17651658          253                   0                  0
# 39     45383893          679                   0                  0
# 46     44291777         3221                   0                  0
# 23    158372072         2437                   0                  0
# 47      7254629           68                   1                  0
# 5      14417872          133                   1                  0
# 4     292903904         1097                   0                  0
# 18    440536571          896                   0                  1
# 45     68194583          107                   0                  0
# 9      79799480          408                   0                  0
# 40   4190823674         4196                   0                  0
# 35     54565589          515                   0                  1
# 1      54565589          515                   1                  0
#
#     comments_emojis_count  ...  country    language  definition       date  \
# 33                      0  ...       CA     English          hd 2019-12-16
# 10                      6  ...       IN       Hindi          hd 2019-08-22
# 6                       0  ...       IN       Hindi          hd 2019-07-19
# 22                      0  ...       US     English          hd 2016-05-02
# 3                       0  ...       US     English          hd 2018-11-27
# 42                      0  ...       TW     Chinese          hd 2013-05-24
# 24                      0  ...       CA     English          hd 2016-01-01
# 32                      0  ...       JP    Japanese          hd 2021-09-22
# 44                      4  ...       FI     Finnish          hd 2018-05-07
# 17                      0  ...       US     English          hd 2015-08-10
# 31                      0  ...       IN       Hindi          hd 2021-01-14
# 41                      0  ...       CA     English          hd 2011-09-29
# 14                      0  ...       DE      German          hd 2022-07-28
# 43                      2  ...       CA     English          hd 2019-12-16
# 27                      0  ...       AU     English          hd 2014-02-01
# 15                      0  ...       CA     English          hd 2008-08-24
# 7                       0  ...       TH        Thai          hd 2013-07-06
# 25                      0  ...       US     English          hd 2016-05-04
# 20                     12  ...       US     English          hd 2019-06-20
# 30                      0  ...       ID  Indonesian          hd 2016-10-04
# 8                       0  ...       GB     English          hd 2020-12-20
# 12                      0  ...       IN       Hindi          hd 2020-09-22
# 0                       2  ...       IN       Hindi          hd 2017-03-12
# 2                       0  ...       FR      French          hd 2016-04-27
# 38                      0  ...       AR     Spanish          hd 2020-02-10
# 29                      0  ...       IN       Hindi          hd 2020-07-31
# 39                      0  ...       MT     Maltese          hd 2016-12-12
# 46                      0  ...       CA     English          hd 2015-12-22
# 23                      0  ...       US     English          hd 2015-11-03
# 47                      0  ...       US     English          hd 2018-01-11
# 5                       0  ...       IN       Hindi          hd 2019-05-04
# 4                       0  ...       US     English          hd 2016-07-01
# 18                      0  ...       PH     Tagalog          hd 2019-07-18
# 45                      0  ...       GB     English          hd 2016-06-02
# 9                       0  ...       US     English          hd 2016-11-15
# 40                      0  ...       CA     English          hd 2008-08-24
# 35                      0  ...       TR     Turkish          hd 2019-03-07
# 1                       0  ...       TR     Turkish          hd 2019-03-07
#
#            publishedAt                                               tags  \
# 33 2023-01-22 09:00:10  ['pubg mobile', 'pubgm', 'pubgmvip', 'PUBG MOB...
# 10 2023-03-02 07:30:08  ['Trolling My New Girlfriend as GIANT ALEX in ...
# 6  2023-03-29 11:46:46  ['kannada songs', 'dv', 'kannada vlog', 'dr br...
# 22 2020-12-15 16:01:57  ['cyberpunk part 2', 'cyberpunk documentary pa...
# 3  2023-01-13 11:00:37  ['dls 23', 'dls', 'dream league soccer 2023', ...
# 42 2022-02-23 09:00:12  ['gameplay', 'ultra settings', 'max settings',...
# 24 2023-03-26 17:15:05  ['kan gaming', 'zeepkist', 'trackmania', 'game...
# 32 2023-03-04 08:00:15  ['humanfallflat', "Johnny'sGamingRoom", 'ジャニーズ...
# 44 2020-07-17 12:00:17  ['ylekioski', 'gaming', 'yle kioski gaming', '...
# 17 2022-11-22 17:00:15  ['StrangeRebelGaming', 'TheStrangeRebel', 'Bri...
# 31 2023-03-18 03:30:02  ['vebv', 'vebv gaming', 'city skylines', 'mine...
# 41 2023-04-03 03:00:17  ['call of duty mobile', 'cod mobile', 'codm', ...
# 14 2023-02-07 17:19:04  ['Lami', 'roblox', 'roblox lami', 'roblox deut...
# 43 2023-02-26 10:00:11  ['pubg mobile', 'pubgm', 'pubgmvip', 'PUBG MOB...
# 27 2023-03-31 20:00:08  ['re4 attention to detail', 'resident evil 4 a...
# 15 2023-03-30 16:00:27                                                 []
# 7  2022-09-25 11:30:13  ['สปอยหนัง', 'หนังสนุก', 'หนังมันส์', 'Spoiler...
# 25 2022-04-29 15:00:35  ['Last of us', 'Fungus', 'CorDyceps', 'Girl', ...
# 20 2023-03-29 02:52:19  ['Mega albino gorilla trades', 'Mega albino go...
# 30 2023-03-22 04:59:21  ['Mobile Legends', 'Mobile Legends: Bang Bang'...
# 8  2023-03-15 16:27:40  ['کالاف دیوتی موبایل', 'کالاف موبایل', 'کالاف ...
# 12 2023-01-02 07:20:02                                                 []
# 0  2022-12-16 13:48:42  ['#crazypanda', 'crazypanda', 'crazy panda gam...
# 2  2023-03-18 09:20:32  ['astuce', 'soluce', 'vf', 'raid', 'raid pokem...
# 38 2023-01-30 20:00:09  ['gta 5', 'gta v', 'grand theft auto 5', 'gran...
# 29 2022-09-26 05:00:15  ['arpus pixelmon', 'arpus pokemon', 'arpus min...
# 39 2021-02-26 11:53:37  ['cemu vulkan', 'cemu async compile', 'cemu gu...
# 46 2023-03-02 15:00:37  ['JonnyFiveAlive', 'Jonny5Alive', 'Channel5 Ga...
# 23 2023-03-30 15:16:33  ['klaus', 'klaus gaming', 'gaming', 'clash of ...
# 47 2020-07-16 00:08:27  ['animal crossing', 'animal crossing new horiz...
# 5  2023-02-27 15:16:48  ['upcoming lighthouse location summertime saga...
# 4  2022-12-13 14:00:00  ['Brawl Stars', 'BrawlStars', 'Kairos', 'Kairo...
# 18 2023-03-02 07:05:09  ['vonordonayt', 'gta', 'gta5', 'billionairecit...
# 45 2020-05-04 08:46:59  ['Top Gear', 'TG', 'Original', 'Old', 'Jeremy ...
# 9  2023-02-01 17:00:49  ['Alpha Gaming', 'Stream Doctor', 'OBS', 'Tips...
# 40 2023-04-01 18:30:56                                                 []
# 35 2022-12-05 12:00:11  ['dkgaming', 'duygu', 'duygu köseoğlu', 'ücret...
# 1  2023-01-07 12:00:21  ['dk gaming', 'duygu köseoğlu', 'dk gaming oyu...
#
#                                          about_tokens  \
# 33                   [blue, channel, welcome, gaming]
# 10  [logo, ish, maro, gaminginsectbusiness, app, g...
# 6   [plz, kannada, free, thank, support, content, ...
# 22  [specification, livestreams, 860, 64bit, plate...
# 3   [highquality, quantity, focus, enquire, video,...
# 42  [如果您覺得本頻道做的不錯歡迎透過, semenixpcgamingblogspottw20...
# 24                                [game, video, life]
# 32  [man, 重岡大毅, 深澤辰哉, 森本慎太郎, say, 佐藤勝利, sexy, ジャニー...
# 44  [peleistä, hauskimmat, täältä, luotsaamana, ki...
# 17  [create, help, base, comment, bri, since, ll, ...
# 31                                       [game, play]
# 41  [stream, release, date, 5, duty, multiplayer, ...
# 14  [um, abonniere, tag, teil, roblox, spiele, den...
# 43                   [blue, channel, welcome, gaming]
# 27  [daily, tiktok, guide, walkthroughs, join, inq...
# 15  [daily, gta, livestreams, s, channel, 5, turn,...
# 7   [fbmegamingfollow, ตดตองาน, http, โลกนมนเครยด,...
# 25  [would, leave, review, zombie, sin, survive, d...
# 20  [dad, watch, roblox, fun, mikedrop937, cammy, ...
# 30  [facebook, moba, gmailcom, channel, welcome, e...
# 8   [دیوتی, پلیر, wwwinstagramcomamininferno, امین...
# 12  [buisness, regard, free, gmailcon, hi, video, ...
# 0   [crazy々panda, trick, recorder, poco, forget, n...
# 2   [uniquement, retrouve, cest, contacter, répond...
# 38  [e, gta, mayor, contenido, v, relacionado, ent...
# 29  [special, you, comment, inquiry, joke, mrmemes...
# 39  [guide, emulation, http, facebook, performance...
# 46  [want, pass, vnand, special, guarantee, twitch...
# 23  [daily, videos, aftershockmediagroupcom, game,...
# 47             [nico, s, hello, nicole, call, friend]
# 5   [officialsummertimegaming, english, walkthroug...
# 4   [want, thing, join, freak, fun, brawl, tick, e...
# 18  [daily, name, pinas, hit, sa, channel, next, h...
# 45                                                 []
# 9   [help, thing, perfect, sponsorship, really, ga...
# 40  [daily, gta, livestreams, s, channel, 5, turn,...
# 35  [daha, duygu, korku, köseoğlu, diyebilirim, ov...
# 1   [daha, duygu, korku, köseoğlu, diyebilirim, ov...
#
#                                          title_tokens  \
# 33                                              [mad]
# 10    [minecraft, girl, i, alex, become, giant, fool]
# 6   [kannada, journey, vlogsnight, express, vasco,...
# 22  [cyberpunk, 2, shell, total, recall, blade, do...
# 3   [r2g, 23, begin, free, coin, super, dls, agent...
# 42  [horizonforbidden, 地平線西域禁地4k電影剪輯版, semenix出品, ...
# 24  [pro, speed, track, love, high, build, precision]
# 32                     [フォール, フラット, 犬ピンチステージアイスヒューマン]
# 44  [c, rankataan, alkuvuoden, parhaat, pelaajat, go]
# 17  [va, simulator, shinra, aerith, final, pt, fan...
# 31          [secret, bunker, 6, house, nuck, flipper]
# 41                   [use, mobile, coupon, time, cod]
# 14          [spielzeug, fabrik, ausbruch, roblox, au]
# 43                [baby, mobile, revenge, pubg, time]
# 27  [15, 4, evil, resident, remake, little, anothe...
# 15                 [ever, trio, fast, game, fortnite]
# 7   [พดไดไมมเบรค, พอลล, l, การเดนทางสดทรหดของนกแกว...
# 25  [would, zombie, girl, survive, nt, apocalypse,...
# 20    [adopt, gorilla, trade, albino, pet, mega, wfl]
# 30  [server, patch, buffnerf, legends, bug, rekap,...
# 8   [مغزبازی, وان, اسنایپ, اس, زون, اچ, آخر, لوت, ...
# 12  [17, कछ, ह, free, top, change, update, क, अजब,...
# 0   [girl, thing, omegle, crazypandagaming, funny,...
# 2   [violet, archéduc, solo, raid, écarlate, réuss...
# 38         [gta, coches, robando, policía, 5, de, en]
# 29  [part2, minecraft, survive, pixelmon, hindi, d...
# 39  [maximum, guide, install, cemu, setup, complet...
# 46  [rid, coaster, theme, park, aventura, mine, tr...
# 23                            [time, max, th10, wall]
# 47  [birthday, caroline, cross, horizon, happy, an...
# 5   [late, tech, update, date, summertime, 02017, ...
# 4                 [worth, upgrading, chester, unlock]
# 18  [semplang, von, sa, ni, track, agad, race, una...
# 45              [moment, series, 2, top, gear, funny]
# 9                          [ever, update, s, big, ob]
# 40                             [fortnite, happen, og]
# 35  [bebek, 4, sims, b2, challenge, çocuklar, 100,...
# 1                   [kedi, rahatlatici, cafe, calico]
#
#           channelTitle_tokens  \
# 33             [blue, gaming]
# 10             [game, insect]
# 6          [game, volter, yt]
# 22           [indigo, gaming]
# 3            [game, hd, gang]
# 42            [game, semenix]
# 24              [gaming, kan]
# 32  [s, johnny, room, gaming]
# 44      [yle, gaming, kioski]
# 17   [rebel, strange, gaming]
# 31             [vebv, gaming]
# 41              [jhc, gaming]
# 14             [lami, gaming]
# 43             [blue, gaming]
# 27         [game, dan, allen]
# 15           [gamer, typical]
# 7              [game, follow]
# 25              [wow, gaming]
# 20      [sopo, squad, gaming]
# 30               [vy, gaming]
# 8     [inferno, amin, gaming]
# 12              [game, enjoy]
# 0      [panda, gaming, crazy]
# 2            [gaming, boramy]
# 38             [vista, gamer]
# 29       [buckethead, gaming]
# 39             [bsod, gaming]
# 46         [channel5, gaming]
# 23            [klaus, gaming]
# 47               [game, nico]
# 5        [summertime, gaming]
# 4        [kairostime, gaming]
# 18      [von, ordona, gaming]
# 45             [game, nonzah]
# 9            [gaming, senpai]
# 40           [gamer, typical]
# 35               [dk, gaming]
# 1                [dk, gaming]
#
#                                    description_tokens
# 33  [rezapanahi299, pubgmvip, wwwinstagramcomblueg...
# 10  [8sister, 4minecraft, war, 5minecraft, install...
# 6   [wwwyoutubecomchannelucprr1j9tbtsatgqd7j3tea, ...
# 22  [cyber, 2010, 5828, 1210, man, ocremixorgremix...
# 3   [r2g, coin, super, instagram, ggofficialcom, a...
# 42  [gc573, 034007, 4k, wwwyoutubecomchanneluc6lhn...
# 24  [storesteampoweredcomapp1440670zeepkist, every...
# 32  [はじめは苦戦するものの持ち前のセンスで, wwwyoutubecomchannelucvm...
# 44  [kioskia, csgo, ehti, robujohnson, youtubecomy...
# 17  [bri, watch, dr, high, instagram, listplens2fu...
# 31  [http, second, wwwyoutubecomcvebvyt, luck, ins...
# 41  [modern, jhc, engage, join, thumb, watch, list...
# 14  [macleod, roblox, http, instagram, emily, wwwr...
# 43  [rezapanahi299, pubgmvip, wwwinstagramcomblueg...
# 27  [tiktok, 556, join, 9, 534, watch, become, awe...
# 15  [everyone, help, comment, ignore, keep, thumb,...
# 7   [tiktok, gmf, fbmegamingfollow, gmfgamingfollo...
# 25  [give, wwwtwitchtvw0wsuchgaming, infection, de...
# 20  [lowkey, glass, thing, join, boba, gorilla, tr...
# 30  [patch, join, watch, instagram, wwwfacebookcom...
# 8          [instagramcomamininferno, http, instagram]
# 12  [special, traininggroundlike, chance, join, fr...
# 0   [vlog, 𝐆𝐚𝐦𝐢𝐧𝐠, http, instagram, forget, gmailc...
# 2   [uniquement, téracristal, rejoin, 00h59, insta...
# 38  [para, gta, también, auto, porque, algo, lo, h...
# 29  [proper, message, everyone, panda, join, watch...
# 39  [patch, optimization, dlc, ram, controller, re...
# 46  [create, 118, planetcoaster, introduction, 522...
# 23  [use, become, http, second, klaus, patreon, id...
# 47  [animalcrossing, macrame, path, nicole, yall, ...
# 5   [man, walkthroughs, small, join, watch, high, ...
# 4   [tribegaminggg, join, twittercomkairostime, in...
# 18  [tiktok, vttiktokcomzs8r85nju, xxl, podcast, c...
# 45            [moment, series, top, 2nd, gear, funny]
# 9   [backtrack, watch, instagram, streambeats, log...
# 40  [everyone, help, comment, ignore, keep, thumb,...
# 35  [köseoğlu, rastgele, candean, bir, ekstralar, ...
# 1   [köseoğlu, bir, ekstralar, twittercomduygubie,...
#
# [38 rows x 24 columns]

# %%
R = 412
r1 = R
r2 = R + 5

id(r2)
# Out:
# 2207201593904

# %%
pd.DataFrame(X_train)

# %% [markdown]
# #### *Training the models*

# %%
[txt_col for txt_col.apply(lambda x: ' '.join(x)) in X[text_cols]]

temp_txt_cols = []

for txt_col in X[text_cols]:
    
    X[txt_col].apply(lambda x: ' '.join(x))
    temp_txt_cols.append(X[txt_col])
    X["my_new_text"]X[text_cols].agg(', '.join, axis=1)

# %%
X["my_new_text"] = X[text_cols].apply(lambda x: ', '.join(x), axis=1)

# %%
X["my_new_text"] = X[text_cols].apply(lambda x: ', '.join(map(str, x)), axis=1)
X["my_new_text"][1]

# %%
tfidf.fit_transform(df[].apply(lambda x: ' '.join(x)))

# %%
def model_report(y_true, y_pred):

    pre = precision_score(y_true, y_pred, average= "micro")
    rec = recall_score(y_true, y_pred, average= "micro")
    f1 = f1_score(y_true, y_pred, average= "micro")
  # loss = log_loss(y_true, y_pred, normalize= False)
    acc = accuracy_score(y_true, y_pred)

    print("| precision: {:4f}        |\n".format(pre) + \
          "| recall: {:4f}           |\n".format(rec) + \
          "| f1-score: {:4f}         |\n".format(f1) + \
          "| accuracy: {:4f}         |".format(acc))
