# %% [markdown]
# ## <center> **Importing the <span style="color: red">Packeges</span>**

# %%
import gc
import pandas as pd
import numpy as np
import matplotlib
import seaborn as sns
import statsmodels.api as sm
import panel as pn
from scipy import stats
import sqlite3
import pickle
# from numba import jit

from IPython.display import set_matplotlib_formats
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
THEME_COLORS = ["#383838", "#ff0000"]
NUMERICS = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
FONT = 13

# set_matplotlib_formats('pdf', 'svg')

# %% [markdown]
# ## <center> **Reading and simple <span style="color: red">exploring</span>**

# %%
con = sqlite3.connect('../database.db')

df = pd.read_sql_query("""-- The outuput of this querry will be assigned to
                          -- `df` variable.

                          SELECT *
                          FROM base_videos
                          INNER JOIN base_channels ON
                          channelTitle = channel_name""", con)

con.close()

# %% [markdown]
# This data frame is a temporary combination for this notebook only to explore the statics for<br>
# our data.

# %%
df.sample(5)
# Out:
#           video_id          channelTitle  \
# 8288   K7QYfR9_y60        Gallant Gaming
# 11272  ImJ4vcIznow           M9D6 Gaming
# 16626  DdqkM26G59o    Top Hat Gaming Man
# 13217  wfURpgHZvOA  The Vaniverse Gaming
# 11102  9W9JbxEzqZs  Strange Rebel Gaming
#
#                                                    title  \
# 8288   Secret Character 11 and Withered Animatronics ...
# 11272                                No Humanity level 2
# 16626  Karate Bikini Babes - A Weird ''Adult'' Fighti...
# 13217  Solasta CoTM: (IRONMAN Mode) EP 24: The Volcan...
# 11102  Rufus & The Turks - Aerith VA Plays Final Fant...
#
#                                              description  \
# 8288   In this video I show you how to get the NEW Se...
# 11272  #shorts \nمتنساش الاشتراك دعم لينا\n\nFacebook...
# 16626  In this video, we look at the history of yet a...
# 13217  This is episode 24 of my Solasta COTM  Scaveng...
# 11102  Cloud, Tifa & Aerith have defeated the JENOVA ...
#
#                                                     tags  \
# 8288   ['roblox', 'roblox fnaf', 'roblox fnaf rp', 'r...
# 11272                                                 []
# 16626  ["Karate Bikini Babes - A Weird ''Adult'' Figh...
# 13217  ['Solasta', 'solasta crown of the magister', '...
# 11102  ['StrangeRebelGaming', 'TheStrangeRebel', 'Bri...
#
#                      publishedAt  viewCount  likeCount  commentCount  \
# 8288   2023-02-11 15:00:12+00:00     183300       3827           365
# 11272  2023-01-24 02:40:39+00:00        117          4             1
# 16626  2022-10-02 20:13:46+00:00      18864       1078           167
# 13217  2022-12-28 17:00:28+00:00         50          1             1
# 11102  2022-12-20 17:00:03+00:00      13927        705           132
#
#       definition  duration_in_minutes          channel_name  subscribers  \
# 8288          hd            11.632812        Gallant Gaming       477000
# 11272         hd             0.500000           M9D6 Gaming         7270
# 16626         hd            20.906250    Top Hat Gaming Man       129000
# 13217         hd            30.031250  The Vaniverse Gaming        37100
# 11102         hd            74.312500  Strange Rebel Gaming       207000
#
#        total_views                 date  video_count  \
# 8288     143443891  2019-04-15 00:00:00         1251
# 11272      3164272  2020-02-12 00:00:00         1744
# 16626     27785807  2016-01-16 00:00:00          754
# 13217      9620057  2014-02-20 00:00:00          232
# 11102     20507678  2015-08-10 00:00:00          365
#
#                                                    about country
# 8288   Daily Roblox Five Nights At Freddys videos!\n\...      US
# 11272                                   we make content       EG
# 16626  The Top Hat Gaming Man is a Gaming YouTuber wh...      GB
# 13217  Welcome to the Vaniverse Gaming Channel. If yo...      US
# 11102  Hi! I'm Bri, and welcome to my channel, Strang...      US

# %%
cm = sns.light_palette(THEME_COLORS[1], as_cmap=True)
df.select_dtypes(NUMERICS).sample(6).style.background_gradient(cmap=cm)
# Out:
# <style type="text/css">
# #T_498f4_row0_col0 {
#   background-color: #f4d8d8;
#   color: #000000;
# }
# #T_498f4_row0_col1 {
#   background-color: #f4d9d9;
#   color: #000000;
# }
# #T_498f4_row0_col2 {
#   background-color: #f5c1c1;
#   color: #000000;
# }
# #T_498f4_row0_col3 {
#   background-color: #f3ebeb;
#   color: #000000;
# }
# #T_498f4_row0_col4 {
#   background-color: #fd2828;
#   color: #f1f1f1;
# }
# #T_498f4_row0_col5 {
#   background-color: #fe1c1c;
#   color: #f1f1f1;
# }
# #T_498f4_row0_col6 {
#   background-color: #fa6060;
#   color: #f1f1f1;
# }
# #T_498f4_row1_col0 {
#   background-color: #f3e3e3;
#   color: #000000;
# }
# #T_498f4_row1_col1 {
#   background-color: #f3e6e6;
#   color: #000000;
# }
# #T_498f4_row1_col2, #T_498f4_row3_col5 {
#   background-color: #f4d0d0;
#   color: #000000;
# }
# #T_498f4_row1_col3, #T_498f4_row2_col0, #T_498f4_row2_col1, #T_498f4_row2_col2, #T_498f4_row2_col4, #T_498f4_row2_col5, #T_498f4_row2_col6 {
#   background-color: #f3f0f0;
#   color: #000000;
# }
# #T_498f4_row1_col4, #T_498f4_row1_col5, #T_498f4_row2_col3, #T_498f4_row3_col2, #T_498f4_row4_col0, #T_498f4_row4_col1, #T_498f4_row5_col6 {
#   background-color: #ff0000;
#   color: #f1f1f1;
# }
# #T_498f4_row1_col6 {
#   background-color: #fa5b5b;
#   color: #f1f1f1;
# }
# #T_498f4_row3_col0 {
#   background-color: #f89393;
#   color: #000000;
# }
# #T_498f4_row3_col1 {
#   background-color: #f6adad;
#   color: #000000;
# }
# #T_498f4_row3_col3 {
#   background-color: #f4e1e1;
#   color: #000000;
# }
# #T_498f4_row3_col4 {
#   background-color: #f89494;
#   color: #000000;
# }
# #T_498f4_row3_col6, #T_498f4_row5_col5 {
#   background-color: #f3e8e7;
#   color: #000000;
# }
# #T_498f4_row4_col2 {
#   background-color: #fc3b3b;
#   color: #f1f1f1;
# }
# #T_498f4_row4_col3 {
#   background-color: #f4d8d7;
#   color: #000000;
# }
# #T_498f4_row4_col4 {
#   background-color: #f6b6b6;
#   color: #000000;
# }
# #T_498f4_row4_col5 {
#   background-color: #f4dddd;
#   color: #000000;
# }
# #T_498f4_row4_col6 {
#   background-color: #f5cdcd;
#   color: #000000;
# }
# #T_498f4_row5_col0 {
#   background-color: #f3e8e8;
#   color: #000000;
# }
# #T_498f4_row5_col1 {
#   background-color: #f3eaea;
#   color: #000000;
# }
# #T_498f4_row5_col2 {
#   background-color: #f3efef;
#   color: #000000;
# }
# #T_498f4_row5_col3 {
#   background-color: #fd2424;
#   color: #f1f1f1;
# }
# #T_498f4_row5_col4 {
#   background-color: #f4e2e2;
#   color: #000000;
# }
# </style>
# <table id="T_498f4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_498f4_level0_col0" class="col_heading level0 col0" >viewCount</th>
#       <th id="T_498f4_level0_col1" class="col_heading level0 col1" >likeCount</th>
#       <th id="T_498f4_level0_col2" class="col_heading level0 col2" >commentCount</th>
#       <th id="T_498f4_level0_col3" class="col_heading level0 col3" >duration_in_minutes</th>
#       <th id="T_498f4_level0_col4" class="col_heading level0 col4" >subscribers</th>
#       <th id="T_498f4_level0_col5" class="col_heading level0 col5" >total_views</th>
#       <th id="T_498f4_level0_col6" class="col_heading level0 col6" >video_count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_498f4_level0_row0" class="row_heading level0 row0" >7121</th>
#       <td id="T_498f4_row0_col0" class="data row0 col0" >102097</td>
#       <td id="T_498f4_row0_col1" class="data row0 col1" >4933</td>
#       <td id="T_498f4_row0_col2" class="data row0 col2" >223</td>
#       <td id="T_498f4_row0_col3" class="data row0 col3" >10.851562</td>
#       <td id="T_498f4_row0_col4" class="data row0 col4" >2890000</td>
#       <td id="T_498f4_row0_col5" class="data row0 col5" >1286573035</td>
#       <td id="T_498f4_row0_col6" class="data row0 col6" >2034</td>
#     </tr>
#     <tr>
#       <th id="T_498f4_level0_row1" class="row_heading level0 row1" >18444</th>
#       <td id="T_498f4_row1_col0" class="data row1 col0" >57470</td>
#       <td id="T_498f4_row1_col1" class="data row1 col1" >2274</td>
#       <td id="T_498f4_row1_col2" class="data row1 col2" >151</td>
#       <td id="T_498f4_row1_col3" class="data row1 col3" >5.648438</td>
#       <td id="T_498f4_row1_col4" class="data row1 col4" >3470000</td>
#       <td id="T_498f4_row1_col5" class="data row1 col5" >1457466637</td>
#       <td id="T_498f4_row1_col6" class="data row1 col6" >2093</td>
#     </tr>
#     <tr>
#       <th id="T_498f4_level0_row2" class="row_heading level0 row2" >11834</th>
#       <td id="T_498f4_row2_col0" class="data row2 col0" >281</td>
#       <td id="T_498f4_row2_col1" class="data row2 col1" >13</td>
#       <td id="T_498f4_row2_col2" class="data row2 col2" >2</td>
#       <td id="T_498f4_row2_col3" class="data row2 col3" >244.500000</td>
#       <td id="T_498f4_row2_col4" class="data row2 col4" >28700</td>
#       <td id="T_498f4_row2_col5" class="data row2 col5" >4594602</td>
#       <td id="T_498f4_row2_col6" class="data row2 col6" >216</td>
#     </tr>
#     <tr>
#       <th id="T_498f4_level0_row3" class="row_heading level0 row3" >5295</th>
#       <td id="T_498f4_row3_col0" class="data row3 col0" >395514</td>
#       <td id="T_498f4_row3_col1" class="data row3 col1" >14025</td>
#       <td id="T_498f4_row3_col2" class="data row3 col2" >1112</td>
#       <td id="T_498f4_row3_col3" class="data row3 col3" >20.593750</td>
#       <td id="T_498f4_row3_col4" class="data row3 col4" >1350000</td>
#       <td id="T_498f4_row3_col5" class="data row3 col5" >202277099</td>
#       <td id="T_498f4_row3_col6" class="data row3 col6" >333</td>
#     </tr>
#     <tr>
#       <th id="T_498f4_level0_row4" class="row_heading level0 row4" >12848</th>
#       <td id="T_498f4_row4_col0" class="data row4 col0" >1022052</td>
#       <td id="T_498f4_row4_col1" class="data row4 col1" >50472</td>
#       <td id="T_498f4_row4_col2" class="data row4 col2" >835</td>
#       <td id="T_498f4_row4_col3" class="data row4 col3" >30.406250</td>
#       <td id="T_498f4_row4_col4" class="data row4 col4" >863000</td>
#       <td id="T_498f4_row4_col5" class="data row4 col5" >123669672</td>
#       <td id="T_498f4_row4_col6" class="data row4 col6" >655</td>
#     </tr>
#     <tr>
#       <th id="T_498f4_level0_row5" class="row_heading level0 row5" >401</th>
#       <td id="T_498f4_row5_col0" class="data row5 col0" >33989</td>
#       <td id="T_498f4_row5_col1" class="data row5 col1" >1373</td>
#       <td id="T_498f4_row5_col2" class="data row5 col2" >9</td>
#       <td id="T_498f4_row5_col3" class="data row5 col3" >208.875000</td>
#       <td id="T_498f4_row5_col4" class="data row5 col4" >231000</td>
#       <td id="T_498f4_row5_col5" class="data row5 col5" >56782080</td>
#       <td id="T_498f4_row5_col6" class="data row5 col6" >3247</td>
#     </tr>
#   </tbody>
# </table>

# %%
cm = sns.light_palette(THEME_COLORS[1], as_cmap=True)
df.describe().style.background_gradient(cmap=cm)
# Out:
# <style type="text/css">
# #T_d31b6_row0_col0, #T_d31b6_row0_col4, #T_d31b6_row0_col5, #T_d31b6_row1_col0, #T_d31b6_row1_col3, #T_d31b6_row3_col0, #T_d31b6_row3_col1, #T_d31b6_row3_col2, #T_d31b6_row3_col3, #T_d31b6_row3_col4, #T_d31b6_row3_col5, #T_d31b6_row3_col6, #T_d31b6_row4_col0, #T_d31b6_row4_col1, #T_d31b6_row4_col2, #T_d31b6_row4_col3, #T_d31b6_row4_col4, #T_d31b6_row4_col5, #T_d31b6_row5_col0, #T_d31b6_row5_col1, #T_d31b6_row5_col2, #T_d31b6_row5_col3, #T_d31b6_row6_col0, #T_d31b6_row6_col1, #T_d31b6_row6_col3 {
#   background-color: #f3f0f0;
#   color: #000000;
# }
# #T_d31b6_row0_col1, #T_d31b6_row5_col5 {
#   background-color: #f3eeee;
#   color: #000000;
# }
# #T_d31b6_row0_col2 {
#   background-color: #f79f9f;
#   color: #000000;
# }
# #T_d31b6_row0_col3, #T_d31b6_row0_col6, #T_d31b6_row7_col0, #T_d31b6_row7_col1, #T_d31b6_row7_col2, #T_d31b6_row7_col4, #T_d31b6_row7_col5 {
#   background-color: #ff0000;
#   color: #f1f1f1;
# }
# #T_d31b6_row1_col1, #T_d31b6_row1_col2, #T_d31b6_row2_col3, #T_d31b6_row5_col4, #T_d31b6_row6_col2 {
#   background-color: #f3efef;
#   color: #000000;
# }
# #T_d31b6_row1_col4, #T_d31b6_row2_col2, #T_d31b6_row6_col5 {
#   background-color: #f3e8e8;
#   color: #000000;
# }
# #T_d31b6_row1_col5 {
#   background-color: #f3e6e6;
#   color: #000000;
# }
# #T_d31b6_row1_col6 {
#   background-color: #f3e4e4;
#   color: #000000;
# }
# #T_d31b6_row2_col0 {
#   background-color: #f3ebeb;
#   color: #000000;
# }
# #T_d31b6_row2_col1 {
#   background-color: #f3e8e7;
#   color: #000000;
# }
# #T_d31b6_row2_col4 {
#   background-color: #f4dada;
#   color: #000000;
# }
# #T_d31b6_row2_col5 {
#   background-color: #f4d5d5;
#   color: #000000;
# }
# #T_d31b6_row2_col6 {
#   background-color: #f4e2e2;
#   color: #000000;
# }
# #T_d31b6_row4_col6 {
#   background-color: #f3eded;
#   color: #000000;
# }
# #T_d31b6_row5_col6 {
#   background-color: #f3e9e9;
#   color: #000000;
# }
# #T_d31b6_row6_col4 {
#   background-color: #f3eaea;
#   color: #000000;
# }
# #T_d31b6_row6_col6 {
#   background-color: #f4e1e1;
#   color: #000000;
# }
# #T_d31b6_row7_col3 {
#   background-color: #f4d8d8;
#   color: #000000;
# }
# #T_d31b6_row7_col6 {
#   background-color: #f79897;
#   color: #000000;
# }
# </style>
# <table id="T_d31b6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d31b6_level0_col0" class="col_heading level0 col0" >viewCount</th>
#       <th id="T_d31b6_level0_col1" class="col_heading level0 col1" >likeCount</th>
#       <th id="T_d31b6_level0_col2" class="col_heading level0 col2" >commentCount</th>
#       <th id="T_d31b6_level0_col3" class="col_heading level0 col3" >duration_in_minutes</th>
#       <th id="T_d31b6_level0_col4" class="col_heading level0 col4" >subscribers</th>
#       <th id="T_d31b6_level0_col5" class="col_heading level0 col5" >total_views</th>
#       <th id="T_d31b6_level0_col6" class="col_heading level0 col6" >video_count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d31b6_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_d31b6_row0_col0" class="data row0 col0" >19343.000000</td>
#       <td id="T_d31b6_row0_col1" class="data row0 col1" >19343.000000</td>
#       <td id="T_d31b6_row0_col2" class="data row0 col2" >19343.000000</td>
#       <td id="T_d31b6_row0_col3" class="data row0 col3" >19343.000000</td>
#       <td id="T_d31b6_row0_col4" class="data row0 col4" >19343.000000</td>
#       <td id="T_d31b6_row0_col5" class="data row0 col5" >19343.000000</td>
#       <td id="T_d31b6_row0_col6" class="data row0 col6" >19343.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d31b6_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_d31b6_row1_col0" class="data row1 col0" >360349.763170</td>
#       <td id="T_d31b6_row1_col1" class="data row1 col1" >11811.349997</td>
#       <td id="T_d31b6_row1_col2" class="data row1 col2" >407.953316</td>
#       <td id="T_d31b6_row1_col3" class="data row1 col3" >46.647296</td>
#       <td id="T_d31b6_row1_col4" class="data row1 col4" >1135767.049113</td>
#       <td id="T_d31b6_row1_col5" class="data row1 col5" >262671207.996329</td>
#       <td id="T_d31b6_row1_col6" class="data row1 col6" >988.942822</td>
#     </tr>
#     <tr>
#       <th id="T_d31b6_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_d31b6_row2_col0" class="data row2 col0" >2711722.219970</td>
#       <td id="T_d31b6_row2_col1" class="data row2 col1" >64863.755746</td>
#       <td id="T_d31b6_row2_col2" class="data row2 col2" >1959.320592</td>
#       <td id="T_d31b6_row2_col3" class="data row2 col3" >89.616236</td>
#       <td id="T_d31b6_row2_col4" class="data row2 col4" >3166012.300229</td>
#       <td id="T_d31b6_row2_col5" class="data row2 col5" >656386437.446411</td>
#       <td id="T_d31b6_row2_col6" class="data row2 col6" >1152.973225</td>
#     </tr>
#     <tr>
#       <th id="T_d31b6_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_d31b6_row3_col0" class="data row3 col0" >1.000000</td>
#       <td id="T_d31b6_row3_col1" class="data row3 col1" >1.000000</td>
#       <td id="T_d31b6_row3_col2" class="data row3 col2" >1.000000</td>
#       <td id="T_d31b6_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_d31b6_row3_col4" class="data row3 col4" >61.000000</td>
#       <td id="T_d31b6_row3_col5" class="data row3 col5" >1.000000</td>
#       <td id="T_d31b6_row3_col6" class="data row3 col6" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d31b6_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_d31b6_row4_col0" class="data row4 col0" >3372.000000</td>
#       <td id="T_d31b6_row4_col1" class="data row4 col1" >140.000000</td>
#       <td id="T_d31b6_row4_col2" class="data row4 col2" >9.000000</td>
#       <td id="T_d31b6_row4_col3" class="data row4 col3" >7.000000</td>
#       <td id="T_d31b6_row4_col4" class="data row4 col4" >49400.000000</td>
#       <td id="T_d31b6_row4_col5" class="data row4 col5" >7848593.000000</td>
#       <td id="T_d31b6_row4_col6" class="data row4 col6" >260.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d31b6_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_d31b6_row5_col0" class="data row5 col0" >24777.000000</td>
#       <td id="T_d31b6_row5_col1" class="data row5 col1" >1206.000000</td>
#       <td id="T_d31b6_row5_col2" class="data row5 col2" >63.000000</td>
#       <td id="T_d31b6_row5_col3" class="data row5 col3" >13.570312</td>
#       <td id="T_d31b6_row5_col4" class="data row5 col4" >236000.000000</td>
#       <td id="T_d31b6_row5_col5" class="data row5 col5" >45433503.000000</td>
#       <td id="T_d31b6_row5_col6" class="data row5 col6" >559.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d31b6_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_d31b6_row6_col0" class="data row6 col0" >136209.000000</td>
#       <td id="T_d31b6_row6_col1" class="data row6 col1" >5815.500000</td>
#       <td id="T_d31b6_row6_col2" class="data row6 col2" >260.000000</td>
#       <td id="T_d31b6_row6_col3" class="data row6 col3" >31.640625</td>
#       <td id="T_d31b6_row6_col4" class="data row6 col4" >863000.000000</td>
#       <td id="T_d31b6_row6_col5" class="data row6 col5" >189310658.000000</td>
#       <td id="T_d31b6_row6_col6" class="data row6 col6" >1263.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d31b6_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_d31b6_row7_col0" class="data row7 col0" >119872567.000000</td>
#       <td id="T_d31b6_row7_col1" class="data row7 col1" >1787829.000000</td>
#       <td id="T_d31b6_row7_col2" class="data row7 col2" >57276.000000</td>
#       <td id="T_d31b6_row7_col3" class="data row7 col3" >1928.000000</td>
#       <td id="T_d31b6_row7_col4" class="data row7 col4" >34700000.000000</td>
#       <td id="T_d31b6_row7_col5" class="data row7 col5" >5648937017.000000</td>
#       <td id="T_d31b6_row7_col6" class="data row7 col6" >7136.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19343 entries, 0 to 19342
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   video_id             19343 non-null  object
#  1   channelTitle         19343 non-null  object
#  2   title                19343 non-null  object
#  3   description          19343 non-null  object
#  4   tags                 19343 non-null  object
#  5   publishedAt          19343 non-null  object
#  6   viewCount            19343 non-null  int64
#  7   likeCount            19343 non-null  int64
#  8   commentCount         19343 non-null  int64
#  9   definition           19343 non-null  object
#  10  duration_in_minutes  19343 non-null  float64
#  11  channel_name         19343 non-null  object
#  12  subscribers          19343 non-null  int64
#  13  total_views          19343 non-null  int64
#  14  date                 19343 non-null  object
#  15  video_count          19343 non-null  int64
#  16  about                19343 non-null  object
#  17  country              19343 non-null  object
# dtypes: float64(1), int64(6), object(11)
# memory usage: 2.7+ MB

# %%
print(f"The data consumation here is: {df.memory_usage(deep= True).sum() // 1024 ** 2} MB")
# Out:
# The data consumation here is: 83 MB

# %% [markdown]
# Now we just need to convert `date col` & `publishedAt` col into *date-time* ones

# %%
df["publishedAt"] = pd.to_datetime(df["publishedAt"])
df["date"] = pd.to_datetime(df["date"])

# %% [markdown]
# ## <strong><center>Visualizing the data<span style= "color: red"> statistics</span>

# %% [markdown]
# #### *Distrbution tests*

# %%
fig = sns.jointplot(data= df, x= "subscribers", y= "video_count",
              color= THEME_COLORS[1],
              marker= "+", s= 100, 
              marginal_kws= dict(bins=25, fill=False))

fig.fig.suptitle('Distribution test for Subscribers Vs Video count')

plt.ticklabel_format(style='plain', axis='y')
plt.ticklabel_format(style='plain', axis='x')


plt.xticks(rotation=90)
plt.yticks(rotation=90)
plt.savefig("../plots/subs_vs_video_count_hist_scatter.svg")
plt.show()

# %%
# sns.jointplot(data= df, x= "duration_in_minutes", y="viewCount", kind="reg")

fig = sns.jointplot(data= df, x= "duration_in_minutes", y= "viewCount",
              color= THEME_COLORS[0], kind="reg",
              marker= "2")

fig.fig.suptitle("Distribution test for Duration in minutes Vs Views")

plt.ticklabel_format(style='plain', axis='y')
plt.ticklabel_format(style='plain', axis='x')

plt.xticks(rotation=90)
plt.yticks(rotation= 0)
plt.savefig("../plots/dur_vs_views_reg_plot.svg")
plt.show()

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows= 2, ncols= 2)

sns.histplot(data= df, x= "subscribers", ax= ax1, bins= 20, color= THEME_COLORS[0]).set_title(
    "Subscribers distrbution (non-edited)")

sns.histplot(data= df, x= "viewCount", ax= ax2, bins= 20, color= THEME_COLORS[0]).set_title(
    "Views distrbution (non-edited)")

sns.histplot(data= df, x= "subscribers", ax= ax3, bins= 20, color= THEME_COLORS[1]).set_title(
    "Subscribers distrbution (log scaled)")
    
sns.histplot(data= df, x= "subscribers", ax= ax4, bins= 20, color= THEME_COLORS[1]).set_title(
    "Views distrbution (log scaled)")


for ax in [ax1, ax2, ax3, ax4]:
    ax.ticklabel_format(style='plain', axis='y')
    ax.ticklabel_format(style='plain', axis='x')

    for tick in ax.get_xticklabels():
        tick.set_rotation(50)

fig.set_size_inches(13, 17)
plt.savefig("../plots/distrbutions_before_and_after_log_scaling.svg")
plt.show()

# %% [markdown]
# #### *Bias checking*

# %%
fig, ax = plt.subplots(1)
country_counts = df['country'].value_counts()

sns.barplot(x= country_counts.keys(), y= country_counts.values,
            color= THEME_COLORS[1], ax= ax)

ax.set_title("Bias checking for countries")

for tick in ax.get_xticklabels():
    tick.set_rotation(90)
    
plt.savefig("../plots/countries_count.svg")
fig.set_size_inches(10, 5)
plt.show()

# %%
definition_counts = df["definition"].value_counts()

plt.pie(labels= definition_counts.keys(),
        x= definition_counts.values,
        colors= THEME_COLORS, autopct='%.1f%%', 
        shadow= True, startangle= 70)

plt.savefig("../plots/video_definition_percentage.svg")
plt.title("Video definition percentage in the data")
plt.show()

# %% [markdown]
# #### *Correlation and outliers analysis*

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)
cm = sns.light_palette(THEME_COLORS[1], as_cmap=True)

# ---------------First axes-----------------
ax1.hist2d(df["viewCount"], df["likeCount"], density= True, cmap= cm,
           bins= 50)

ax1.set_title("Views Vs Likes (without edits)")
ax1.ticklabel_format(style='plain', axis='y')
ax1.ticklabel_format(style='plain', axis='x')

for tick in ax1.get_xticklabels():
    tick.set_rotation(50)
    
ax1.set_xlabel("Views")
ax1.set_ylabel("Likes")
# -----------------------------------------


# ----------------Second axes----------------
outliers = tucky_method(df["viewCount"].to_numpy())
outliers_indexes = np.array(*np.where(np.isin(df["viewCount"], outliers)))
no_outliers_df = df.drop(outliers_indexes)

ax2.hist2d(no_outliers_df["viewCount"], no_outliers_df["likeCount"], density= True, cmap= cm,
           bins= 50)

ax2.set_title("Views Vs Likes after tucky method")
ax2.set_xlabel("Views")
ax2.set_ylabel("Likes")

for tick in ax2.get_xticklabels():
    tick.set_rotation(50)
# -----------------------------------------


fig.set_size_inches(12, 5)
plt.savefig("../plots/views_vs_likes_2D_hist.svg")
plt.show()
# Out:
# Found 2523 outliers from 19343 length series!

# %%
corr = df.corr(numeric_only= True, method= "spearman")
cm = sns.light_palette(THEME_COLORS[1], as_cmap=True)

sns.heatmap(corr, annot=True, fmt=".2f", cmap= cm)
plt.title("Spearman correlation cofficient heatmap")

plt.savefig("../plots/spear_man_corr_heatmap.svg")
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(2)
green_diamond = dict(markerfacecolor= THEME_COLORS[1], marker='s')


ax1.set_title('Subscriber boxplot')
ax1.boxplot(df["subscribers"], vert=False, flierprops=green_diamond)


ax2.set_title('Views boxplot')
ax2.boxplot(df["viewCount"], vert=False, flierprops=green_diamond)

plt.savefig("../plots/subs_and_views_box_plot.svg")
fig.set_size_inches(10, 8)
plt.show()

# %% [markdown]
# ## <center><strong><span style= "color: red">Outliers</span> detection algorithm

# %% [markdown]
# **Important note**: We will just right the algorithm that we will use and detect the outliers<br>
# (not dropping them) we will just view them and save this function to use later.<br>
# Here we will just view it's performance compared to other algorithms and save the best.

# %% [markdown]
# #### **Hampel filter**

# %% [markdown]
# We will use hampal filter algorithm you can find more [**Here**](https://towardsdatascience.com/outlier-detection-with-hampel-filter-85ddf523c73d) and here's it's theory:<br>
# $H_i = median(|x_j - x_i|): j ∈ [i - k, i + k]$<br>
# where $k$ is a constant usually equalls the scale factor for the gussian distbution<br>
# which equalls $1.4826$

# %%
test_col = df["viewCount"].to_numpy() 
# we will use this column as test for our algorithms performances

# %%
# @jit(nopython= True)
def hampel_filter(array: np.array, window_size: int, n_sigmas: int= 3) -> list:
    """
    This function takes an array-like numerical object with
    window size, sigmas count to get the outliers of the
    array
    
    :Params: series: list-like
             window_size: int
             n_sigmas: int (default is 3)
             
    :Returns: indices: list (indexes of the founded outliers)
    """
    
    n: int = len(array)
    K: float = 1.4826
    indices = []
    
    for i in range((window_size),(n - window_size)):
        
        x0 = np.median(array[(i - window_size):(i + window_size)])
        S0 = K * np.median(np.abs(array[(i - window_size):(i + window_size)] - x0))
        
        if (np.abs(array[i] - x0) > n_sigmas * S0):
            indices.append(i)
    
    print(f"Found {len(indices)} outliers from {len(array)} length series!")
    
    return indices

# %%
hampel_indices = hampel_filter(test_col, window_size= 10, n_sigmas= 3)
hampel_outliers = test_col[hampel_indices]
# Out:
# Found 4553 outliers from 19343 length series!

# %%
print(f" The standard deviation of the original column is: {np.std(test_col):.0f}\n",
      f"But now it's {np.std(np.setdiff1d(test_col, hampel_outliers)):.0f}")
# Out:
#  The standard deviation of the original column is: 2711652
#  But now it's 66471

# %% [markdown]
# This means that this algorithm cutted down the STD of the test column into it's half<br>
# with just dropping  less than it's quarter.

# %% [markdown]
# #### **Tucky method**

# %% [markdown]
# Now we will try [**Tucky method**](https://www.google.com) it's strong algorithm so it's not good for limited data<br>
# but we will try it and here's it's theory:<br>
# $Upper\;limit = Q3 + (IQR\times1.5)$<br>
# $Lower\;limit = Q1 - (IQR\times1.5)$<br><br>
# any higher number than Upper limit is dropped and vica versa.

# %%
# @jit
def tucky_method(array: np.array, indecies= True) -> np.array:
    """
    This function works with any list-like numerical object
    (don't work with pandas series's) and returns the indexes
    of the found outliers in the array.
    
    :Params: Takes only the series.
    :Returns: S list of the outliers indexes.
    """
    
    Q3 = np.quantile(array, 0.75)
    Q1 = np.quantile(array, 0.25)
    IQR = Q3 - Q1
    
    upper_range = Q3 + (IQR * 1.5)
    lower_range = Q1 - (IQR * 1.5)
    
    outliers = [x for x in array if ((x < lower_range) | (x > upper_range))]
    print(f"Found {len(outliers)} outliers from {len(array)} length series!")
    
    return outliers

# %%
tucky_outliers = tucky_method(test_col)
tucky_indices = np.array(*np.where(np.isin(test_col, tucky_outliers)))
# Out:
# Found 2523 outliers from 19343 length series!

# %%
print(f" The standard deviation of the original column is: {np.std(test_col):.0f}\n",
      f"But now it's {np.std(np.setdiff1d(test_col, tucky_outliers)):.0f}")
# Out:
#  The standard deviation of the original column is: 2711652
#  But now it's 78767

# %% [markdown]
# #### **$\textbf{Z}$-score method**

# %% [markdown]
# Z-score outlier detection method is very soft method that tries to drop the most<br>
# of the strong outliers only and here's it's theory:<br>
# $Upper\;limit = \mu + (3\times\sigma)$<br>
# $Lower\;limit = \mu - (3\times\sigma)$

# %%
# @jit
def z_score(array, indecies= True) -> np.array:
    """
    This function uses Z-score outlier detection method
    to detect outliers and return them into array.

    :Params: array: list-like numerical object
    :Returns: outliers: np.array (array of the outliers)
    """
    
    std: float = array.std()
    mean: float = array.mean()
    
    upper_limit = mean + (3 * std)
    lower_limit = mean - (3 * std)

    outliers = [value for value in array if 
        (value > upper_limit) | (value < lower_limit)]

    print(f"Found {len(outliers)} outliers from {len(array)} length series!")

    return outliers

# %%
z_score_outliers = z_score(test_col)
z_score_indices = np.array(*np.where(np.isin(test_col, z_score_outliers)))
# Out:
# Found 118 outliers from 19343 length series!

# %%
print(f" The standard deviation of the original column is: {np.std(test_col):.0f}\n",
      f"But now it's {np.std(np.setdiff1d(test_col, z_score_outliers)):.0f}")
# Out:
#  The standard deviation of the original column is: 2711652
#  But now it's 649836

# %% [markdown]
# #### **Visualizing thier performance**

# %%
fig, ax = plt.subplots(1)

ax.plot(test_col, color= THEME_COLORS[0])
ax.scatter(hampel_indices, test_col[hampel_indices], s= 7, c= THEME_COLORS[1])

ax.ticklabel_format(style='plain')

ax.get_yaxis().set_major_formatter(
        matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))

fig.set_size_inches(12, 5)
fig.text(.13, .8, "*The red dots are the detected outliers.\n with the algorithm")

plt.title("Hampel filter performance line chart")
plt.savefig("../plots/hampel_filter_performance.svg")
plt.show()

# %%
fig, ax = plt.subplots(1)

ax.plot(test_col, color= THEME_COLORS[0])
ax.scatter(tucky_indices, test_col[tucky_indices], s= 7, c= THEME_COLORS[1])

ax.ticklabel_format(style='plain')

ax.get_yaxis().set_major_formatter(
        matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))

fig.set_size_inches(12, 5)
plt.title("Tucky method performance line chart")
plt.savefig("../plots/tucky_method_performance.svg")
plt.show()

# %%
fig, ax = plt.subplots(1)

ax.plot(test_col, color= THEME_COLORS[0])
ax.scatter(z_score_indices, test_col[z_score_indices], s= 7, c= THEME_COLORS[1])

ax.ticklabel_format(style='plain')

ax.get_yaxis().set_major_formatter(
        matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))

fig.set_size_inches(12, 5)
plt.title("Z-score method performance line chart")
plt.savefig("../plots/z_score_performance.svg")
plt.show()
